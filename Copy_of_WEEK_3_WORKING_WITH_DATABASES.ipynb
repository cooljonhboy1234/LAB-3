# %% [markdown]
# <a href="https://colab.research.google.com/github/cooljonhboy1234/LAB-3/blob/main/Copy_of_WEEK_3_WORKING_WITH_DATABASES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LAB 3: WORKING WITH DATABASES

# %% [markdown]
# ## Introduction
#
# During this lab, we will experiment with using a few different libararies and modules to connect to and interact with an SQLite database. After creating and configuring our testing database, we will populate it with Fake data and run some queries to see what kind of information we can retreive. For context, we will be creating RSSN, the "Really Simple Social Network".

# %% [markdown]
# ## Creating a SQLite Database
#
# We will be utilizing the `sqlite3` library to create our database file, as it offers the convienience of creating our database file automatically in the event that it cannot find an existing file at the path specified.
#
# **Before you run the below code:**
# On the left of the notebook, select the file folder icon. Then, after you run the code block, you should be able to observe the creation of the database file. If it doesn't appear, try clicking the "Refresh" button above the list of folders.

# %%
import sqlite3

#When we retreive a Connection object, a new database will be created for us if it doesn't already exist. 
myConnection = sqlite3.connect('social_network.db')
print(sqlite3.version)
# Out:
# 2.6.0

# %% [markdown]
# ## Creating a Table

# %% [markdown]
# We'll use the below code to create a table called `people` within our database.

# %%
import sqlite3

#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#Let's define the SQL Query we will use to create our first table:
createPeopleTable = """ CREATE TABLE IF NOT EXISTS people (
                          id integer PRIMARY KEY,
                          name text NOT NULL,
                          email text NOT NULL,
                          address text NOT NULL,
                          city text NOT NULL,
                          province text NOT NULL,
                          country text NOT NULL,
                          phone text,
                          bio text,
                          dob date NOT NULL,
                          heatmap integer,
                          created_at datetime NOT NULL,
                          updated_at datetime NOT NULL,
                          ipv4 text
                        );"""

#Now that we have the string to create our table,
#Cursor objects have an execute() method which will accept an SQL string and perform the operations described.

myCursor.execute(createPeopleTable)

#We can confirm if our table was created successfully by running the following SQL Query
#pragma_table_info is an internal SQLite function that will retun information about a table
myCursor.execute("SELECT group_concat(name, ', ') FROM pragma_table_info('people')")
print(myCursor.fetchone())

#We use to the commit() method on the database Connection object to persist our changes
myConnection.commit()

#It is always a good idea to close a connection when it will no longer be used
myConnection.close()
# Out:
# ('id, name, email, address, city, province, country, phone, bio, dob, heatmap, created_at, updated_at, ipv4',)

# %% [markdown]
# If you received a tuple containing the names of the columns, awesome! We have successfully created our database table.
# ```
# ('id, name, email, address, city, province, country, phone, bio, created_at, updated_at',)
# ```
#
# Run the below code block to add our first entry.

# %%
import sqlite3
from pprint import pprint #Outputs data in a slightly easier to read format
from datetime import datetime #For generating dates and times

#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#Let's define the SQL Query we will use to create our first entry:
addPersonQuery = """INSERT INTO people (name, 
                      email, 
                      address, 
                      city, 
                      province, 
                      country, 
                      phone, 
                      bio,
                      dob,
                      heatmap,
                      created_at, 
                      updated_at, 
                      ipv4)
                  VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?);"""

"""
The ?'s are placeholders that we can fill in when we use the execute() method.
This is really handy for code reuse, as we can pass those values are variables in a tuple
Instead of hard coding them into the statement.
"""

myPerson = ("John Doe", 
            "johndoe@anon.null", 
            "123 Fake St.", 
            "Fakesville", 
            "Fakesdom", 
            "Fakopolis", 
            None, 
            None,
            "1967-09-12",
            0,
            datetime.now(), 
            datetime.now(),
            None)

myCursor.execute(addPersonQuery, myPerson)

#We can confirm if our table was created successfully by running the following SQL Query
#pragma_table_info is an internal SQLite function that will retun information about a table
myCursor.execute("SELECT * FROM people")
pprint(myCursor.fetchall())

# If you run this code block a few times, you will see that you only have 1 entry,
# If you uncomment the below lines and run the block a few more times, you will begin to see multiple entries.
# Out:
# [(1,
#   'John Doe',
#   'johndoe@anon.null',
#   '123 Fake St.',
#   'Fakesville',
#   'Fakesdom',
#   'Fakopolis',
#   None,
#   None,
#   '1967-09-12',
#   0,
#   '2021-02-16 23:04:43.207770',
#   '2021-02-16 23:04:43.207784',
#   None)]

# %% [markdown]
# # Lab Submission

# %% [markdown]
# We're going to build our experience with working with Libraries and examining documentation by populating our 'People' table with data provided to us by the `Faker` library. `Faker` is used to generate fake data and is very helpful for the rapid generation of databases for the purposes of testing. Run the two blocks below to install faker and get an idea of what it can do.

# %%
# !pip install faker
# Out:
# Requirement already satisfied: faker in /usr/local/lib/python3.6/dist-packages (6.1.1)
# Requirement already satisfied: text-unidecode==1.3 in /usr/local/lib/python3.6/dist-packages (from faker) (1.3)
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.6/dist-packages (from faker) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.4->faker) (1.15.0)

# %%
from faker import Faker

fake = Faker()

for _ in range(10):
  print('{} || {}'.format( fake.name(), fake.job() ) )
# Out:
# Richard West || Orthoptist
# Joshua Mckee || Conservator, furniture
# Paige Maxwell || Investment analyst
# Lynn Maxwell || Press sub
# Shane Maldonado || Scientist, product/process development
# Cole Stafford || Wellsite geologist
# Stephanie Hunter || Lecturer, further education
# Deborah Adams || Sales professional, IT
# Andrea Miles || Rural practice surveyor
# John Holmes || Engineer, land

# %% [markdown]
# Very cool! Faker has tons of `providers` that can all be used to populate fake data. The [list of providers](https://faker.readthedocs.io/en/stable/providers.html) in the Faker documentation will help you fill out the columns for our People table.
#
# The goal of this script is to populate the people table with 1000 entries, with the following constraints:
#
# 1. The `heatmap` column must contain a random number between `999` and `2500`
# 2. The `created_at` and `updated_at` columns must use the `datetime` object (see examples above)
# 2. Use `Faker` to generate all other fields.
#
# *Hint: Each of the methods contained in the provider can be called directly from the base Faker object, for example, one can call the `file_name()` method from `faker.providers.file` by calling `Faker().file_name()`*

# %%
import sqlite3
from random import randint
from faker import Faker
from datetime import datetime 
#For generating dates and times
#Don't forget to import the module to generate random numbers!

fake = Faker('en_CA')

#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#This is the same syntax as the above example:
count = 1

while count <= 1000:
  
  #random numbers for heatmap
  ranNum = randint(999, 2500)

  addPersonQuery = """INSERT INTO people (name, 
                        email, 
                        address, 
                        city, 
                        province, 
                        country, 
                        phone, 
                        bio,
                        dob,
                        heatmap,
                        created_at, 
                        updated_at, 
                        ipv4)
                    VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?);"""

  myPerson = (fake.name(), 
            fake.email(), 
            fake.street_address(), 
            fake.city(), 
            fake.province(), 
            fake.country(),
            fake.phone_number(), 
            fake.bs(), 
            fake.date_of_birth(),
            ranNum,
            datetime.now(), 
            datetime.now(),
            fake.ipv4_public())

  myCursor.execute(addPersonQuery, myPerson)
  count += 1

myCursor.execute("SELECT * FROM people")
pprint(myCursor.fetchall())
#Ideally, you will want to create a loop that will iterate 1000 times,
#Observe the example in the earlier code block showing the parameter tuple `myPerson`
#You can duplicate that inside your loop and replace those fields with calls to the appropriate faker provider method
#Execute your statement inside the loop,
#But, don't forget to commit and close your connection when you have finished!
myConnection.commit()
myConnection.close()
# Out:
# Streaming output truncated to the last 5000 lines.
#   '2021-02-16 23:04:49.719567',
#   '71.130.27.159'),
#  (644,
#   'Renee Ray',
#   'robert86@yahoo.com',
#   '0025 Jeremy View Apt. 216',
#   'Barrettchester',
#   'Quebec',
#   'Senegal',
#   '(465) 602-3023',
#   'synthesize front-end web-readiness',
#   '1998-01-13',
#   2209,
#   '2021-02-16 23:04:49.720103',
#   '2021-02-16 23:04:49.720104',
#   '122.233.156.22'),
#  (645,
#   'Samantha Jackson',
#   'amandadavis@anderson.com',
#   '6714 Calvin Village Apt. 309',
#   'Christopherchester',
#   'Alberta',
#   'Italy',
#   '(732) 548-0701',
#   'mesh seamless info-mediaries',
#   '1915-08-14',
#   2210,
#   '2021-02-16 23:04:49.720924',
#   '2021-02-16 23:04:49.720925',
#   '173.141.75.15'),
#  (646,
#   'Hannah Daugherty',
#   'donna20@yahoo.com',
#   '0937 Anderson Course Suite 373',
#   'Jimborough',
#   'Yukon Territory',
#   'Bolivia',
#   '855 598 7088',
#   'target intuitive supply-chains',
#   '1971-11-04',
#   1133,
#   '2021-02-16 23:04:49.721478',
#   '2021-02-16 23:04:49.721479',
#   '198.220.229.44'),
#  (647,
#   'Mrs. Kristen Shelton',
#   'robertosmith@harris.org',
#   '29129 Rhonda Fort Apt. 276',
#   'Georgemouth',
#   'British Columbia',
#   'Guyana',
#   '1-514-318-6101',
#   'synthesize extensible synergies',
#   '1910-10-03',
#   2112,
#   '2021-02-16 23:04:49.722356',
#   '2021-02-16 23:04:49.722357',
#   '212.65.197.40'),
#  (648,
#   'Rita Baker',
#   'stonekenneth@gmail.com',
#   '73344 Walsh Via Apt. 822',
#   'Hallberg',
#   'Manitoba',
#   'Rwanda',
#   '+1 (945) 353-3902',
#   'synthesize synergistic systems',
#   '1919-01-20',
#   1862,
#   '2021-02-16 23:04:49.722989',
#   '2021-02-16 23:04:49.722990',
#   '152.20.105.148'),
#  (649,
#   'Daniel Jackson',
#   'pcasey@yahoo.com',
#   '85116 April Court',
#   'Kyleville',
#   'Nova Scotia',
#   'Iran',
#   '1-262-626-8892',
#   'drive viral niches',
#   '2015-07-06',
#   1492,
#   '2021-02-16 23:04:49.723530',
#   '2021-02-16 23:04:49.723531',
#   '185.174.127.43'),
#  (650,
#   'Kent Warren',
#   'ttaylor@king-reynolds.com',
#   '03177 Alvarez Bridge Apt. 311',
#   'Port Bradley',
#   'Saskatchewan',
#   'Saint Vincent and the Grenadines',
#   '(744) 665-2060',
#   'cultivate extensible applications',
#   '1919-05-01',
#   1108,
#   '2021-02-16 23:04:49.724270',
#   '2021-02-16 23:04:49.724271',
#   '214.204.243.151'),
#  (651,
#   'David Mclaughlin',
#   'sbarrera@chase.net',
#   '24359 Taylor Vista Suite 101',
#   'Nealville',
#   'Nunavut',
#   'Kuwait',
#   '265.516.0770',
#   'synergize B2C e-services',
#   '1915-07-25',
#   1585,
#   '2021-02-16 23:04:49.725074',
#   '2021-02-16 23:04:49.725075',
#   '195.116.158.129'),
#  (652,
#   'Micheal Nunez',
#   'bmartin@yahoo.com',
#   '30337 Edwards Manors Suite 647',
#   'Robertsville',
#   'Ontario',
#   'Romania',
#   '122-866-7357 x354',
#   'streamline best-of-breed solutions',
#   '1955-05-27',
#   2263,
#   '2021-02-16 23:04:49.725662',
#   '2021-02-16 23:04:49.725663',
#   '220.128.244.241'),
#  (653,
#   'Kara Collins',
#   'emily42@yahoo.com',
#   '93979 Michelle Vista Suite 361',
#   'South Nicole',
#   'Newfoundland and Labrador',
#   'Kenya',
#   '1-320-548-7574',
#   'redefine impactful communities',
#   '2005-07-24',
#   1923,
#   '2021-02-16 23:04:49.726190',
#   '2021-02-16 23:04:49.726191',
#   '210.148.35.52'),
#  (654,
#   'Sheena Reed',
#   'fherman@shaffer-lawrence.info',
#   '9301 Wilson Drives Apt. 374',
#   'New Vincent',
#   'Quebec',
#   'Niue',
#   '(108) 775-8906',
#   'empower magnetic action-items',
#   '1976-01-27',
#   1426,
#   '2021-02-16 23:04:49.726908',
#   '2021-02-16 23:04:49.726909',
#   '196.135.187.91'),
#  (655,
#   'Joseph Allen',
#   'dgriffin@callahan.com',
#   '52169 Rhodes Points Apt. 535',
#   'Morganmouth',
#   'New Brunswick',
#   'Saint Martin',
#   '717.454.1640',
#   'generate wireless content',
#   '1909-11-22',
#   2013,
#   '2021-02-16 23:04:49.727730',
#   '2021-02-16 23:04:49.727731',
#   '154.95.65.173'),
#  (656,
#   'Amanda Garza',
#   'torreskarina@hotmail.com',
#   '0543 Laura Corner Apt. 622',
#   'Port Elizabeth',
#   'Prince Edward Island',
#   'Cameroon',
#   '1-176-036-7192',
#   'visualize web-enabled architectures',
#   '2012-01-10',
#   2450,
#   '2021-02-16 23:04:49.728328',
#   '2021-02-16 23:04:49.728329',
#   '222.237.89.155'),
#  (657,
#   'Jackie Thornton',
#   'patrick20@atkinson.com',
#   '9369 Julie Centers',
#   'South Laura',
#   'Quebec',
#   'Indonesia',
#   '(860) 993-7894',
#   'aggregate synergistic schemas',
#   '1942-12-29',
#   1176,
#   '2021-02-16 23:04:49.728942',
#   '2021-02-16 23:04:49.728943',
#   '114.110.78.127'),
#  (658,
#   'James Kennedy',
#   'lewisjoseph@morgan.com',
#   '155 Michelle Ranch Apt. 134',
#   'North Bradley',
#   'British Columbia',
#   'Dominican Republic',
#   '+1 (563) 304-5457',
#   'implement real-time schemas',
#   '2014-12-21',
#   2321,
#   '2021-02-16 23:04:49.729768',
#   '2021-02-16 23:04:49.729769',
#   '187.166.23.73'),
#  (659,
#   'Tara White',
#   'juliehorne@russell.info',
#   '0752 Brewer Mountains Suite 445',
#   'West Jennifer',
#   'Yukon Territory',
#   'Portugal',
#   '126-828-1235 x421',
#   'synthesize 24/365 paradigms',
#   '1916-03-03',
#   1666,
#   '2021-02-16 23:04:49.730636',
#   '2021-02-16 23:04:49.730637',
#   '6.137.222.158'),
#  (660,
#   'David Kane',
#   'shepherdjennifer@moreno-jones.info',
#   '73000 Sawyer Well Suite 530',
#   'South William',
#   'Manitoba',
#   'British Virgin Islands',
#   '815.874.7255',
#   'reinvent cross-media schemas',
#   '1914-09-20',
#   2262,
#   '2021-02-16 23:04:49.731543',
#   '2021-02-16 23:04:49.731544',
#   '101.3.180.197'),
#  (661,
#   'Brooke Valenzuela DDS',
#   'jtaylor@thompson-watkins.org',
#   '491 Martinez Radial',
#   'East Alyssashire',
#   'Newfoundland and Labrador',
#   'Kazakhstan',
#   '418-850-6273 x011',
#   'incubate proactive mindshare',
#   '1992-03-03',
#   1735,
#   '2021-02-16 23:04:49.732331',
#   '2021-02-16 23:04:49.732332',
#   '147.9.4.178'),
#  (662,
#   'Christopher Martinez',
#   'patrickwoodward@yahoo.com',
#   '82705 Cassidy Village',
#   'Thomasview',
#   'New Brunswick',
#   'Honduras',
#   '1-531-457-2469',
#   're-intermediate seamless architectures',
#   '2017-05-12',
#   1337,
#   '2021-02-16 23:04:49.732917',
#   '2021-02-16 23:04:49.732918',
#   '205.201.186.68'),
#  (663,
#   'Jessica Woods',
#   'ericbyrd@hotmail.com',
#   '57438 Mcdonald Via Apt. 716',
#   'Lake Nathaniel',
#   'Nova Scotia',
#   'Sudan',
#   '+1 (818) 797-7524',
#   'matrix interactive synergies',
#   '1922-10-02',
#   1568,
#   '2021-02-16 23:04:49.733560',
#   '2021-02-16 23:04:49.733561',
#   '200.91.44.107'),
#  (664,
#   'Christopher Dixon',
#   'alexis00@gmail.com',
#   '0097 Allen Centers',
#   'Lake Brianview',
#   'Northwest Territories',
#   'Libyan Arab Jamahiriya',
#   '+1 (653) 910-0906',
#   'whiteboard dot-com networks',
#   '1985-06-25',
#   2260,
#   '2021-02-16 23:04:49.734108',
#   '2021-02-16 23:04:49.734109',
#   '34.2.172.126'),
#  (665,
#   'Angela Marshall',
#   'billylee@kidd-greene.com',
#   '9105 Smith Mount',
#   'Brianfurt',
#   'Quebec',
#   'Brazil',
#   '(181) 981-6285 x693',
#   'engage next-generation web-readiness',
#   '1933-07-29',
#   1902,
#   '2021-02-16 23:04:49.734879',
#   '2021-02-16 23:04:49.734880',
#   '137.234.54.31'),
#  (666,
#   'Kathleen Wagner',
#   'llong@hotmail.com',
#   '336 Romero Corner Suite 863',
#   'New Paulville',
#   'Nunavut',
#   'Djibouti',
#   '557.740.9145',
#   'evolve mission-critical e-markets',
#   '2000-11-21',
#   1258,
#   '2021-02-16 23:04:49.735446',
#   '2021-02-16 23:04:49.735447',
#   '6.117.161.252'),
#  (667,
#   'David Johnson',
#   'hrivas@young.net',
#   '238 Denise River Apt. 703',
#   'North Kimberlyton',
#   'Nunavut',
#   'Albania',
#   '(820) 812-4093',
#   'iterate out-of-the-box models',
#   '1963-05-21',
#   1178,
#   '2021-02-16 23:04:49.736222',
#   '2021-02-16 23:04:49.736223',
#   '198.88.83.137'),
#  (668,
#   'Hannah Anderson',
#   'stacey14@yahoo.com',
#   '19898 Dylan Mills',
#   'Port Charlesview',
#   'Ontario',
#   'Lebanon',
#   '(959) 195-1842 x072',
#   'monetize cutting-edge users',
#   '1960-09-02',
#   1740,
#   '2021-02-16 23:04:49.736741',
#   '2021-02-16 23:04:49.736742',
#   '191.204.19.30'),
#  (669,
#   'Eric Jones',
#   'catherinesmith@buckley.com',
#   '2573 Young Courts Suite 529',
#   'Port Johntown',
#   'Newfoundland and Labrador',
#   'Paraguay',
#   '579-807-0855',
#   'leverage B2C platforms',
#   '1939-02-07',
#   1805,
#   '2021-02-16 23:04:49.737590',
#   '2021-02-16 23:04:49.737591',
#   '135.2.33.108'),
#  (670,
#   'Amanda Bowen',
#   'fcarson@sherman.com',
#   '1842 Duane Summit',
#   'Gonzalezborough',
#   'Quebec',
#   'Aruba',
#   '(836) 721-6269',
#   'reinvent value-added e-business',
#   '2016-10-10',
#   2384,
#   '2021-02-16 23:04:49.738246',
#   '2021-02-16 23:04:49.738247',
#   '184.73.250.98'),
#  (671,
#   'Jill Jones',
#   'stevecallahan@yahoo.com',
#   '7669 Garcia Forest',
#   'North Jessicaton',
#   'Quebec',
#   'Fiji',
#   '773 955 7848',
#   'empower cutting-edge experiences',
#   '1950-03-30',
#   1588,
#   '2021-02-16 23:04:49.738851',
#   '2021-02-16 23:04:49.738852',
#   '145.219.51.19'),
#  (672,
#   'Danielle Marshall',
#   'mistyvelazquez@holt.biz',
#   '567 Aaron Key',
#   'Johnsonfurt',
#   'New Brunswick',
#   'Malawi',
#   '494-715-7888 x940',
#   'exploit leading-edge portals',
#   '2011-04-21',
#   2467,
#   '2021-02-16 23:04:49.739542',
#   '2021-02-16 23:04:49.739544',
#   '45.30.2.60'),
#  (673,
#   'Kristy Haas',
#   'qcollins@gmail.com',
#   '1090 Carrie Shore Apt. 009',
#   'West Julie',
#   'Northwest Territories',
#   'Iran',
#   '(475) 862-4423',
#   'brand frictionless relationships',
#   '1958-08-18',
#   1659,
#   '2021-02-16 23:04:49.740075',
#   '2021-02-16 23:04:49.740076',
#   '210.166.237.106'),
#  (674,
#   'Tyler Lewis',
#   'wlong@yahoo.com',
#   '1838 Russell Shore Suite 790',
#   'Yatesview',
#   'Nunavut',
#   'Congo',
#   '1-368-638-4298',
#   'facilitate plug-and-play initiatives',
#   '1998-02-17',
#   1432,
#   '2021-02-16 23:04:49.740659',
#   '2021-02-16 23:04:49.740660',
#   '198.217.54.109'),
#  (675,
#   'Michael Cannon',
#   'isalas@phillips.com',
#   '2940 Cox Manor Suite 019',
#   'Lake Kayla',
#   'Yukon Territory',
#   'Norfolk Island',
#   '188 181 2617',
#   'utilize rich e-tailers',
#   '1956-04-28',
#   2055,
#   '2021-02-16 23:04:49.741321',
#   '2021-02-16 23:04:49.741322',
#   '47.128.52.36'),
#  (676,
#   'Hayden Martinez',
#   'edwinsalazar@gmail.com',
#   '25638 Harrison Causeway Apt. 852',
#   'Longfort',
#   'Northwest Territories',
#   'Heard Island and McDonald Islands',
#   '1-355-633-7569',
#   'generate front-end initiatives',
#   '2010-06-07',
#   1554,
#   '2021-02-16 23:04:49.741972',
#   '2021-02-16 23:04:49.741974',
#   '193.236.158.21'),
#  (677,
#   'Samantha Long',
#   'sesparza@yahoo.com',
#   '18835 Charles Groves',
#   'Thomasville',
#   'Alberta',
#   'Chad',
#   '1-295-964-9862',
#   'target clicks-and-mortar markets',
#   '1929-03-14',
#   1135,
#   '2021-02-16 23:04:49.742531',
#   '2021-02-16 23:04:49.742532',
#   '165.180.126.232'),
#  (678,
#   'Grace Nunez',
#   'williamjames@yahoo.com',
#   '4966 Stephen Parks Apt. 231',
#   'East Jennifer',
#   'Saskatchewan',
#   'Guinea',
#   '(177) 309-5786 x968',
#   'evolve B2C applications',
#   '2015-05-10',
#   1760,
#   '2021-02-16 23:04:49.743118',
#   '2021-02-16 23:04:49.743120',
#   '200.39.179.216'),
#  (679,
#   'Bianca Maynard',
#   'cynthiaboyle@smith-blanchard.com',
#   '49519 Smith Hollow Apt. 311',
#   'Curryland',
#   'Nunavut',
#   'Pakistan',
#   '736-528-0590',
#   'drive plug-and-play applications',
#   '1938-06-09',
#   1827,
#   '2021-02-16 23:04:49.743956',
#   '2021-02-16 23:04:49.743957',
#   '219.213.64.20'),
#  (680,
#   'Kyle Mueller',
#   'crawfordanthony@byrd.com',
#   '83247 Sarah Lights Apt. 062',
#   'Lake Deborah',
#   'Newfoundland and Labrador',
#   'Nauru',
#   '546-102-7541',
#   'matrix efficient info-mediaries',
#   '1985-09-24',
#   1568,
#   '2021-02-16 23:04:49.744653',
#   '2021-02-16 23:04:49.744654',
#   '114.19.196.50'),
#  (681,
#   'Thomas Stewart',
#   'jamesmccarthy@gmail.com',
#   '2576 Daniel Spur Apt. 453',
#   'Stephensberg',
#   'Northwest Territories',
#   'Namibia',
#   '(954) 182-2911 x273',
#   'aggregate transparent channels',
#   '1915-04-12',
#   1886,
#   '2021-02-16 23:04:49.745298',
#   '2021-02-16 23:04:49.745299',
#   '75.52.165.147'),
#  (682,
#   'Samantha Harris',
#   'sue43@hendricks.com',
#   '14654 Katie Trafficway Suite 485',
#   'West Rachelchester',
#   'New Brunswick',
#   'Belgium',
#   '(365) 970-5636',
#   'revolutionize innovative ROI',
#   '1988-07-18',
#   2435,
#   '2021-02-16 23:04:49.746270',
#   '2021-02-16 23:04:49.746271',
#   '96.91.101.227'),
#  (683,
#   'Robert Warren',
#   'wcooper@martinez.com',
#   '557 Brent Isle Apt. 524',
#   'East Danielland',
#   'Prince Edward Island',
#   'France',
#   '148.396.7829',
#   'deliver cutting-edge models',
#   '1973-02-21',
#   1414,
#   '2021-02-16 23:04:49.747061',
#   '2021-02-16 23:04:49.747062',
#   '206.158.73.99'),
#  (684,
#   'Noah Horton',
#   'bernardbelinda@white.org',
#   '6224 Brandy Land',
#   'Blackberg',
#   'Nova Scotia',
#   'Russian Federation',
#   '787.784.1998',
#   'e-enable innovative web-readiness',
#   '1954-08-22',
#   1856,
#   '2021-02-16 23:04:49.747902',
#   '2021-02-16 23:04:49.747903',
#   '201.41.201.234'),
#  (685,
#   'Jesse Robinson',
#   'alexray@hester.com',
#   '380 Cobb Crescent',
#   'Perezshire',
#   'New Brunswick',
#   'Jersey',
#   '648 480 9365',
#   'utilize robust supply-chains',
#   '1994-09-07',
#   1669,
#   '2021-02-16 23:04:49.748770',
#   '2021-02-16 23:04:49.748771',
#   '222.235.108.199'),
#  (686,
#   'Angela Johnson',
#   'whitney20@turner-howard.org',
#   '2859 Craig Drive Suite 384',
#   'Hollandborough',
#   'Quebec',
#   'Jamaica',
#   '+1 (177) 733-7826',
#   'scale rich e-markets',
#   '1955-02-24',
#   2317,
#   '2021-02-16 23:04:49.749492',
#   '2021-02-16 23:04:49.749493',
#   '196.156.142.159'),
#  (687,
#   'Nathan Holland',
#   'stephanie80@singleton-stout.com',
#   '6130 Black Squares',
#   'Angelahaven',
#   'Nunavut',
#   'Antarctica (the territory South of 60 deg S)',
#   '+1 (600) 728-3406',
#   'maximize synergistic infrastructures',
#   '1954-03-13',
#   1882,
#   '2021-02-16 23:04:49.750190',
#   '2021-02-16 23:04:49.750191',
#   '155.25.71.215'),
#  (688,
#   'Jeremy Kent',
#   'wisegary@hotmail.com',
#   '250 Marshall Lane',
#   'Michaelshire',
#   'Quebec',
#   'Svalbard & Jan Mayen Islands',
#   '+1 (412) 604-2590',
#   'matrix plug-and-play partnerships',
#   '1906-05-06',
#   1365,
#   '2021-02-16 23:04:49.750806',
#   '2021-02-16 23:04:49.750808',
#   '174.86.250.180'),
#  (689,
#   'Noah Harris',
#   'bernardjaime@gmail.com',
#   '39860 Jones Divide Apt. 195',
#   'Kennethborough',
#   'Yukon Territory',
#   'Malta',
#   '(166) 275-1727',
#   'matrix mission-critical e-markets',
#   '2001-03-17',
#   1263,
#   '2021-02-16 23:04:49.751519',
#   '2021-02-16 23:04:49.751520',
#   '29.167.135.234'),
#  (690,
#   'Theresa Garcia',
#   'annettehudson@yahoo.com',
#   '3429 Pitts Cove Apt. 317',
#   'Port Ryanborough',
#   'Nova Scotia',
#   'South Georgia and the South Sandwich Islands',
#   '143-689-3293 x507',
#   'deploy vertical vortals',
#   '1922-08-07',
#   2379,
#   '2021-02-16 23:04:49.752185',
#   '2021-02-16 23:04:49.752186',
#   '176.62.129.194'),
#  (691,
#   'Christine Bryant',
#   'anna06@suarez-mcpherson.com',
#   '842 Jennifer Fork',
#   'Bryantview',
#   'Newfoundland and Labrador',
#   'Estonia',
#   '333-402-7430',
#   'innovate bricks-and-clicks deliverables',
#   '1906-11-29',
#   2446,
#   '2021-02-16 23:04:49.752880',
#   '2021-02-16 23:04:49.752881',
#   '105.41.216.152'),
#  (692,
#   'Julia Butler',
#   'michaelkaiser@yahoo.com',
#   '48496 Wayne Hollow',
#   'South Jose',
#   'Saskatchewan',
#   'Saint Barthelemy',
#   '227 848 8921',
#   'cultivate best-of-breed e-markets',
#   '1915-05-26',
#   1978,
#   '2021-02-16 23:04:49.753471',
#   '2021-02-16 23:04:49.753472',
#   '98.118.134.27'),
#  (693,
#   'Chelsea Sullivan MD',
#   'cynthiahall@hamilton.info',
#   '13995 Hoffman Meadows Apt. 855',
#   'Steventown',
#   'Quebec',
#   'Jordan',
#   '+1 (830) 356-2703',
#   'seize integrated solutions',
#   '1981-09-29',
#   1626,
#   '2021-02-16 23:04:49.754197',
#   '2021-02-16 23:04:49.754199',
#   '53.88.106.183'),
#  (694,
#   'Stephen Martin',
#   'qdavis@ray-lopez.net',
#   '59785 George Streets',
#   'Port Jacquelineshire',
#   'Ontario',
#   'Saint Barthelemy',
#   '239-900-4089',
#   'grow dynamic partnerships',
#   '1948-03-14',
#   2446,
#   '2021-02-16 23:04:49.754884',
#   '2021-02-16 23:04:49.754885',
#   '146.53.195.98'),
#  (695,
#   'Roger Peterson',
#   'jasonlogan@mendoza-conner.org',
#   '58775 Mack Passage',
#   'Alexanderbury',
#   'Saskatchewan',
#   'Myanmar',
#   '(635) 104-2918',
#   'synthesize synergistic users',
#   '1991-04-15',
#   1672,
#   '2021-02-16 23:04:49.755636',
#   '2021-02-16 23:04:49.755637',
#   '207.16.102.94'),
#  (696,
#   'Isaac Peters',
#   'lewissteven@yahoo.com',
#   '032 Spencer Centers',
#   'West Roberto',
#   'Alberta',
#   'Antigua and Barbuda',
#   '+1 (575) 198-4643',
#   'whiteboard B2C info-mediaries',
#   '1915-09-19',
#   1628,
#   '2021-02-16 23:04:49.756239',
#   '2021-02-16 23:04:49.756240',
#   '115.58.175.173'),
#  (697,
#   'Scott Leon',
#   'melissa78@nguyen.biz',
#   '7644 Jason Road',
#   'North Kristen',
#   'Saskatchewan',
#   'Greece',
#   '677.139.8879',
#   'architect rich action-items',
#   '1933-03-08',
#   1284,
#   '2021-02-16 23:04:49.756989',
#   '2021-02-16 23:04:49.756990',
#   '222.38.234.121'),
#  (698,
#   'Amber Williams',
#   'amanda80@banks.org',
#   '647 Maria Drive Suite 610',
#   'New Daniel',
#   'Northwest Territories',
#   'Niue',
#   '+1 (397) 405-8303',
#   'architect virtual applications',
#   '1940-09-23',
#   1939,
#   '2021-02-16 23:04:49.757797',
#   '2021-02-16 23:04:49.757798',
#   '129.77.5.35'),
#  (699,
#   'Justin Franklin',
#   'mwright@miles.com',
#   '91131 Carolyn Keys',
#   'Castrostad',
#   'Newfoundland and Labrador',
#   'Maldives',
#   '598 108 3044',
#   'productize efficient e-business',
#   '1976-05-08',
#   2377,
#   '2021-02-16 23:04:49.758624',
#   '2021-02-16 23:04:49.758626',
#   '153.150.128.144'),
#  (700,
#   'Julia Mcknight',
#   'reesemelissa@yahoo.com',
#   '645 Gary Cove Apt. 674',
#   'Oliverchester',
#   'Newfoundland and Labrador',
#   'Cook Islands',
#   '165-928-5790',
#   'visualize compelling relationships',
#   '1984-01-21',
#   2005,
#   '2021-02-16 23:04:49.759260',
#   '2021-02-16 23:04:49.759261',
#   '202.93.90.42'),
#  (701,
#   'Allison Todd',
#   'heatherdavis@yahoo.com',
#   '421 Arthur Rapid',
#   'New Lawrence',
#   'Manitoba',
#   'Korea',
#   '960.584.9136',
#   'deliver front-end bandwidth',
#   '1997-11-01',
#   1812,
#   '2021-02-16 23:04:49.759837',
#   '2021-02-16 23:04:49.759838',
#   '195.253.151.39'),
#  (702,
#   'Xavier Harris',
#   'barbara82@ruiz.com',
#   '842 Ross Valley',
#   'New Davidville',
#   'Nunavut',
#   'Philippines',
#   '1-282-681-9652',
#   'exploit cross-media e-services',
#   '1957-03-27',
#   1062,
#   '2021-02-16 23:04:49.760615',
#   '2021-02-16 23:04:49.760616',
#   '185.200.156.16'),
#  (703,
#   'Dennis Beard',
#   'christopher74@gmail.com',
#   '991 Megan Springs Apt. 428',
#   'Drakeberg',
#   'Quebec',
#   'Switzerland',
#   '1 (101) 410-6705',
#   'morph enterprise platforms',
#   '1960-03-15',
#   1370,
#   '2021-02-16 23:04:49.761151',
#   '2021-02-16 23:04:49.761152',
#   '216.16.104.235'),
#  (704,
#   'Amber Jones',
#   'michael43@greene-burke.info',
#   '23759 Harmon View Suite 291',
#   'West Brittany',
#   'Ontario',
#   'Micronesia',
#   '1-330-996-2155',
#   'scale wireless initiatives',
#   '1983-02-09',
#   1436,
#   '2021-02-16 23:04:49.761871',
#   '2021-02-16 23:04:49.761872',
#   '121.25.26.140'),
#  (705,
#   'Miranda Shaw',
#   'thompsonjeremy@warren.com',
#   '86916 Courtney Ramp Apt. 686',
#   'Kimberlymouth',
#   'Prince Edward Island',
#   'Egypt',
#   '1-561-259-0132',
#   'grow 24/365 bandwidth',
#   '1950-09-02',
#   1720,
#   '2021-02-16 23:04:49.762574',
#   '2021-02-16 23:04:49.762575',
#   '203.117.103.8'),
#  (706,
#   'Paula Cruz',
#   'stacey11@hotmail.com',
#   '61378 Morgan Springs',
#   'East Stephen',
#   'New Brunswick',
#   'Guernsey',
#   '(471) 290-8948',
#   'innovate value-added networks',
#   '1944-03-20',
#   2301,
#   '2021-02-16 23:04:49.763138',
#   '2021-02-16 23:04:49.763140',
#   '202.20.56.24'),
#  (707,
#   'Stephanie Norton',
#   'kylenelson@gmail.com',
#   '9423 Walters Ridges',
#   'South Wandaville',
#   'Quebec',
#   'Indonesia',
#   '(547) 026-5282',
#   'integrate granular experiences',
#   '1905-09-15',
#   1807,
#   '2021-02-16 23:04:49.763780',
#   '2021-02-16 23:04:49.763781',
#   '116.151.106.63'),
#  (708,
#   'Stephanie Hawkins',
#   'ulong@gmail.com',
#   '79397 Thomas Harbors Apt. 232',
#   'Port Ashley',
#   'Yukon Territory',
#   'Nigeria',
#   '+1 (916) 089-8639',
#   'expedite 24/365 e-commerce',
#   '1974-02-26',
#   1782,
#   '2021-02-16 23:04:49.764353',
#   '2021-02-16 23:04:49.764354',
#   '195.161.159.47'),
#  (709,
#   'John Brown',
#   'fcraig@archer-moreno.com',
#   '92066 Geoffrey Corner',
#   'Amberburgh',
#   'Nova Scotia',
#   'Kyrgyz Republic',
#   '880 570 0988',
#   'scale 24/365 methodologies',
#   '1998-12-25',
#   1829,
#   '2021-02-16 23:04:49.765047',
#   '2021-02-16 23:04:49.765048',
#   '1.254.118.91'),
#  (710,
#   'Amanda Ramirez',
#   'nrobinson@lambert.com',
#   '75295 Tamara Greens Suite 880',
#   'Bakermouth',
#   'Prince Edward Island',
#   'Cameroon',
#   '1 (774) 236-5623',
#   'mesh vertical e-tailers',
#   '2017-10-29',
#   1279,
#   '2021-02-16 23:04:49.765851',
#   '2021-02-16 23:04:49.765852',
#   '60.27.230.132'),
#  (711,
#   'Kristina Coleman',
#   'joel53@hotmail.com',
#   '9278 Tammy Drive Apt. 084',
#   'Kathleenmouth',
#   'New Brunswick',
#   'China',
#   '1 (406) 589-2840',
#   'aggregate proactive architectures',
#   '1936-05-14',
#   1028,
#   '2021-02-16 23:04:49.766373',
#   '2021-02-16 23:04:49.766374',
#   '60.199.148.91'),
#  (712,
#   'Brian Davis',
#   'zclark@hotmail.com',
#   '5552 Anderson Mews',
#   'Michelechester',
#   'Ontario',
#   'Burkina Faso',
#   '1 (603) 731-6223',
#   'repurpose frictionless systems',
#   '1973-09-02',
#   1730,
#   '2021-02-16 23:04:49.766910',
#   '2021-02-16 23:04:49.766911',
#   '131.138.225.204'),
#  (713,
#   'Luis Bonilla',
#   'clarkroger@martin.com',
#   '703 Kirby Green Suite 774',
#   'South Travisville',
#   'Northwest Territories',
#   'United Arab Emirates',
#   '(474) 358-9789',
#   'aggregate out-of-the-box solutions',
#   '1906-06-20',
#   1001,
#   '2021-02-16 23:04:49.767748',
#   '2021-02-16 23:04:49.767749',
#   '189.113.86.134'),
#  (714,
#   'Heidi Fernandez',
#   'kristyowen@gmail.com',
#   '208 Harris Avenue Apt. 202',
#   'West Kim',
#   'Saskatchewan',
#   'Barbados',
#   '(610) 812-2939',
#   'maximize user-centric relationships',
#   '1916-05-18',
#   1684,
#   '2021-02-16 23:04:49.768362',
#   '2021-02-16 23:04:49.768363',
#   '163.26.88.144'),
#  (715,
#   'Kim Houston',
#   'powellkevin@yahoo.com',
#   '6821 Shepherd Lights Apt. 081',
#   'Port Cherylburgh',
#   'Ontario',
#   'Romania',
#   '(623) 916-3618 x847',
#   'brand interactive technologies',
#   '1964-08-09',
#   1953,
#   '2021-02-16 23:04:49.768988',
#   '2021-02-16 23:04:49.768989',
#   '211.240.43.250'),
#  (716,
#   'Christian Jackson',
#   'fcasey@gmail.com',
#   '71129 Richard Ways',
#   'Bentleytown',
#   'Nunavut',
#   'Heard Island and McDonald Islands',
#   '(788) 806-7649',
#   'enable user-centric convergence',
#   '1988-05-01',
#   1697,
#   '2021-02-16 23:04:49.769550',
#   '2021-02-16 23:04:49.769551',
#   '85.131.199.242'),
#  (717,
#   'Rachel Peterson DDS',
#   'rodneytran@yahoo.com',
#   '888 Sullivan Key Suite 981',
#   'Lisafurt',
#   'British Columbia',
#   'Turkey',
#   '794 405 9009',
#   're-intermediate visionary partnerships',
#   '1949-10-26',
#   1814,
#   '2021-02-16 23:04:49.770175',
#   '2021-02-16 23:04:49.770176',
#   '168.147.207.144'),
#  (718,
#   'Derek Decker',
#   'theresa59@gmail.com',
#   '97855 Jeffery Square',
#   'West Whitneymouth',
#   'Nova Scotia',
#   'Romania',
#   '435-910-8524 x133',
#   'incubate one-to-one content',
#   '1965-02-13',
#   1017,
#   '2021-02-16 23:04:49.770712',
#   '2021-02-16 23:04:49.770713',
#   '174.99.204.89'),
#  (719,
#   'Paul Bright',
#   'amanda94@hotmail.com',
#   '3640 Shawn Ports Suite 011',
#   'Alisonmouth',
#   'Quebec',
#   'Bangladesh',
#   '857-201-8408 x396',
#   'matrix holistic web-readiness',
#   '2005-02-05',
#   1516,
#   '2021-02-16 23:04:49.771242',
#   '2021-02-16 23:04:49.771243',
#   '180.192.225.18'),
#  (720,
#   'Michael Cook',
#   'hillchristine@davis.com',
#   '798 Francis Tunnel',
#   'Parksburgh',
#   'Newfoundland and Labrador',
#   'Svalbard & Jan Mayen Islands',
#   '(573) 802-6959',
#   'iterate B2C networks',
#   '1965-09-14',
#   2351,
#   '2021-02-16 23:04:49.771944',
#   '2021-02-16 23:04:49.771945',
#   '206.248.88.26'),
#  (721,
#   'Leah Gross',
#   'cbailey@gordon.com',
#   '50696 Johnson Corners',
#   'Patriciatown',
#   'Northwest Territories',
#   'United States of America',
#   '299.640.0096',
#   'expedite customized channels',
#   '1967-08-05',
#   2444,
#   '2021-02-16 23:04:49.772738',
#   '2021-02-16 23:04:49.772739',
#   '216.168.180.153'),
#  (722,
#   'Miguel Garza',
#   'zherrera@petersen-delgado.com',
#   '509 Heather Tunnel Apt. 147',
#   'Sancheztown',
#   'Nunavut',
#   'United States Minor Outlying Islands',
#   '1-359-950-5539',
#   'incentivize leading-edge content',
#   '2001-06-27',
#   2196,
#   '2021-02-16 23:04:49.773498',
#   '2021-02-16 23:04:49.773499',
#   '166.31.106.108'),
#  (723,
#   'Christopher Farrell',
#   'ereid@rodriguez.info',
#   '287 Chandler Mall',
#   'Scottborough',
#   'Alberta',
#   'Fiji',
#   '(201) 535-7365 x825',
#   'orchestrate real-time schemas',
#   '1925-08-01',
#   2315,
#   '2021-02-16 23:04:49.774290',
#   '2021-02-16 23:04:49.774291',
#   '177.0.45.93'),
#  (724,
#   'Cody York',
#   'jamie42@yahoo.com',
#   '75144 Jon Isle',
#   'North Andrew',
#   'British Columbia',
#   'China',
#   '1 (783) 741-0937',
#   'incubate plug-and-play functionalities',
#   '1940-01-09',
#   2256,
#   '2021-02-16 23:04:49.774790',
#   '2021-02-16 23:04:49.774791',
#   '46.163.176.75'),
#  (725,
#   'Travis Lopez',
#   'albert87@simmons-escobar.info',
#   '28797 Lawrence Knoll Suite 252',
#   'Smithfurt',
#   'Nunavut',
#   'United States Minor Outlying Islands',
#   '1-669-271-9053',
#   'engage visionary info-mediaries',
#   '1917-05-14',
#   1256,
#   '2021-02-16 23:04:49.775543',
#   '2021-02-16 23:04:49.775545',
#   '119.91.205.125'),
#  (726,
#   'Brittany Hogan',
#   'krystalmills@yahoo.com',
#   '6209 Larsen Path Suite 504',
#   'West Micheal',
#   'Yukon Territory',
#   'Djibouti',
#   '125 215 1446',
#   'extend customized info-mediaries',
#   '2017-11-13',
#   1994,
#   '2021-02-16 23:04:49.776158',
#   '2021-02-16 23:04:49.776159',
#   '27.103.220.236'),
#  (727,
#   'Curtis Pham',
#   'tammyperry@gmail.com',
#   '709 Meredith Key',
#   'Port Rileychester',
#   'Quebec',
#   "Cote d'Ivoire",
#   '+1 (804) 691-0728',
#   'synergize scalable content',
#   '1922-04-28',
#   1483,
#   '2021-02-16 23:04:49.776743',
#   '2021-02-16 23:04:49.776744',
#   '99.139.168.198'),
#  (728,
#   'Brian Bryant',
#   'crystalbrown@hotmail.com',
#   '39280 Allison Canyon',
#   'Brownville',
#   'Ontario',
#   'Thailand',
#   '(662) 842-5499',
#   'embrace web-enabled niches',
#   '2014-09-22',
#   2469,
#   '2021-02-16 23:04:49.777335',
#   '2021-02-16 23:04:49.777337',
#   '220.162.21.215'),
#  (729,
#   'Matthew Bradshaw',
#   'josephvelasquez@burns.com',
#   '846 Michele Drives Suite 797',
#   'Nicholasside',
#   'New Brunswick',
#   'Finland',
#   '+1 (947) 999-9538',
#   'monetize viral partnerships',
#   '1983-09-12',
#   1513,
#   '2021-02-16 23:04:49.778010',
#   '2021-02-16 23:04:49.778011',
#   '160.250.43.76'),
#  (730,
#   'Valerie Hernandez',
#   'wdavis@kelley.net',
#   '664 Michael Heights',
#   'New Sarah',
#   'Manitoba',
#   'Armenia',
#   '448-713-9486 x441',
#   'redefine cross-platform markets',
#   '1934-03-26',
#   1744,
#   '2021-02-16 23:04:49.778708',
#   '2021-02-16 23:04:49.778709',
#   '181.248.184.55'),
#  (731,
#   'Glenn Thompson',
#   'vincentbell@wilson.com',
#   '28838 Pamela Rapids',
#   'Port Samantha',
#   'Alberta',
#   'Faroe Islands',
#   '1-286-855-0485',
#   'morph killer niches',
#   '1998-09-30',
#   1336,
#   '2021-02-16 23:04:49.779534',
#   '2021-02-16 23:04:49.779535',
#   '222.197.151.18'),
#  (732,
#   'Kristen Smith',
#   'freemanmaria@moon-navarro.com',
#   '0584 Parks Curve Suite 576',
#   'Anthonystad',
#   'Nova Scotia',
#   'Christmas Island',
#   '+1 (884) 763-2126',
#   'exploit robust technologies',
#   '2013-05-25',
#   1125,
#   '2021-02-16 23:04:49.780319',
#   '2021-02-16 23:04:49.780320',
#   '198.106.121.12'),
#  (733,
#   'Lucas Foster',
#   'sandrastark@smith-fowler.com',
#   '40669 Cooper Road Apt. 687',
#   'Martinhaven',
#   'Manitoba',
#   'Barbados',
#   '882.925.7908',
#   'streamline e-business systems',
#   '1978-04-15',
#   1474,
#   '2021-02-16 23:04:49.781111',
#   '2021-02-16 23:04:49.781112',
#   '219.92.176.183'),
#  (734,
#   'Amanda Cuevas',
#   'tuckerdavid@lucero.com',
#   '121 Xavier Walk Apt. 141',
#   'East Stephen',
#   'Manitoba',
#   'British Indian Ocean Territory (Chagos Archipelago)',
#   '203-703-2577',
#   'redefine transparent e-services',
#   '2014-06-08',
#   2390,
#   '2021-02-16 23:04:49.781941',
#   '2021-02-16 23:04:49.781942',
#   '196.160.108.232'),
#  (735,
#   'Charles Barrett',
#   'denise44@yahoo.com',
#   '3821 Phillips Burgs',
#   'Kevinbury',
#   'Ontario',
#   'Saint Barthelemy',
#   '+1 (252) 590-1093',
#   'strategize visionary niches',
#   '1959-05-07',
#   1344,
#   '2021-02-16 23:04:49.782474',
#   '2021-02-16 23:04:49.782475',
#   '189.35.114.95'),
#  (736,
#   'Elaine Bishop',
#   'ztorres@robertson-smith.com',
#   '843 Hutchinson Burg Suite 895',
#   'Brianview',
#   'Nova Scotia',
#   'Suriname',
#   '(653) 208-8343 x790',
#   'whiteboard extensible convergence',
#   '1966-10-14',
#   1437,
#   '2021-02-16 23:04:49.783207',
#   '2021-02-16 23:04:49.783208',
#   '198.43.211.115'),
#  (737,
#   'Elizabeth Clark',
#   'sextongabrielle@hotmail.com',
#   '47005 Silva Causeway',
#   'Lake Ryan',
#   'British Columbia',
#   'American Samoa',
#   '554 135 8229',
#   'revolutionize efficient deliverables',
#   '1959-11-16',
#   2482,
#   '2021-02-16 23:04:49.783821',
#   '2021-02-16 23:04:49.783822',
#   '112.127.8.57'),
#  (738,
#   'Danielle Contreras',
#   'uarmstrong@gmail.com',
#   '26645 White Island Suite 898',
#   'East Joshua',
#   'British Columbia',
#   'Hungary',
#   '(732) 921-4527 x236',
#   'incentivize e-business solutions',
#   '2002-09-19',
#   2040,
#   '2021-02-16 23:04:49.784393',
#   '2021-02-16 23:04:49.784394',
#   '195.202.215.68'),
#  (739,
#   'Stephanie Brown',
#   'lopezaustin@smith.com',
#   '937 William Roads',
#   'West Christopher',
#   'Northwest Territories',
#   'Sudan',
#   '911.408.6691',
#   'incentivize virtual deliverables',
#   '2002-12-10',
#   1747,
#   '2021-02-16 23:04:49.785058',
#   '2021-02-16 23:04:49.785059',
#   '193.14.140.49'),
#  (740,
#   'Dylan Hart',
#   'michael48@hotmail.com',
#   '13253 Diana Parks Apt. 583',
#   'New Jeromeside',
#   'Manitoba',
#   'Bouvet Island (Bouvetoya)',
#   '505.840.9752',
#   'enable leading-edge metrics',
#   '1934-11-03',
#   2483,
#   '2021-02-16 23:04:49.785624',
#   '2021-02-16 23:04:49.785625',
#   '184.151.236.203'),
#  (741,
#   'Justin Clark',
#   'vaughnraymond@yahoo.com',
#   '4266 Taylor Stream',
#   'West Zacharyport',
#   'Ontario',
#   'Korea',
#   '739-111-4759',
#   'benchmark cross-platform infrastructures',
#   '1980-03-16',
#   1803,
#   '2021-02-16 23:04:49.786372',
#   '2021-02-16 23:04:49.786373',
#   '152.205.238.175'),
#  (742,
#   'Brian Wise',
#   'armstrongsandra@gmail.com',
#   '760 Nolan Stravenue Suite 399',
#   'Lake Rachelhaven',
#   'Ontario',
#   'India',
#   '1-125-368-4821',
#   'deploy clicks-and-mortar methodologies',
#   '1947-06-24',
#   1926,
#   '2021-02-16 23:04:49.787013',
#   '2021-02-16 23:04:49.787015',
#   '144.87.56.198'),
#  (743,
#   'Kathryn Wolfe',
#   'oyoung@yahoo.com',
#   '3724 Jackson Crossing Suite 231',
#   'Maldonadoberg',
#   'Yukon Territory',
#   'Kiribati',
#   '(169) 821-5347',
#   'empower synergistic vortals',
#   '1964-10-17',
#   1950,
#   '2021-02-16 23:04:49.787578',
#   '2021-02-16 23:04:49.787580',
#   '130.183.253.219'),
#  (744,
#   'Todd Johnson',
#   'nadams@hotmail.com',
#   '039 Denise Forest Apt. 538',
#   'East Christopherbury',
#   'Saskatchewan',
#   'Uruguay',
#   '307-034-6578 x716',
#   'morph intuitive solutions',
#   '1968-04-30',
#   1531,
#   '2021-02-16 23:04:49.788119',
#   '2021-02-16 23:04:49.788120',
#   '27.206.32.152'),
#  (745,
#   'Amy Rice',
#   'jenniferanderson@gmail.com',
#   '119 Alex Cliff Suite 124',
#   'Lake Steve',
#   'Nova Scotia',
#   'Myanmar',
#   '1-224-852-8988',
#   'matrix scalable technologies',
#   '1968-07-11',
#   1896,
#   '2021-02-16 23:04:49.788731',
#   '2021-02-16 23:04:49.788732',
#   '214.181.6.161'),
#  (746,
#   'Gregory Smith',
#   'juliatorres@johnston.info',
#   '00538 Walton Harbor',
#   'Lake Adrienneborough',
#   'Alberta',
#   'New Caledonia',
#   '(383) 040-6568',
#   'cultivate world-class eyeballs',
#   '2006-10-22',
#   2050,
#   '2021-02-16 23:04:49.789442',
#   '2021-02-16 23:04:49.789443',
#   '153.127.86.102'),
#  (747,
#   'Joseph Hayden PhD',
#   'gonzalezamanda@gmail.com',
#   '3909 Smith Vista Suite 879',
#   'Kathyside',
#   'Alberta',
#   'Cook Islands',
#   '1-398-776-9465',
#   'matrix seamless synergies',
#   '1949-08-23',
#   1838,
#   '2021-02-16 23:04:49.790209',
#   '2021-02-16 23:04:49.790210',
#   '4.239.210.113'),
#  (748,
#   'Melanie Morgan',
#   'yhicks@frazier.com',
#   '41033 Martin Springs Suite 792',
#   'Lake Christopher',
#   'Northwest Territories',
#   'Pitcairn Islands',
#   '1-604-596-6765',
#   'aggregate granular info-mediaries',
#   '2014-01-05',
#   1275,
#   '2021-02-16 23:04:49.791044',
#   '2021-02-16 23:04:49.791045',
#   '195.93.37.166'),
#  (749,
#   'William Garcia',
#   'jennifer69@hotmail.com',
#   '94185 Morris Brooks',
#   'Anitaburgh',
#   'British Columbia',
#   'Congo',
#   '975 568 8274',
#   'evolve wireless metrics',
#   '1930-05-07',
#   1533,
#   '2021-02-16 23:04:49.791655',
#   '2021-02-16 23:04:49.791656',
#   '163.248.50.43'),
#  (750,
#   'Ashley Walker',
#   'rriley@yahoo.com',
#   '749 Douglas Roads Suite 475',
#   'Matthewland',
#   'Manitoba',
#   'Russian Federation',
#   '+1 (648) 989-4074',
#   'mesh clicks-and-mortar applications',
#   '1950-07-22',
#   1045,
#   '2021-02-16 23:04:49.792237',
#   '2021-02-16 23:04:49.792238',
#   '8.170.136.236'),
#  (751,
#   'Billy Mendoza',
#   'kimberlytorres@gmail.com',
#   '0772 Rosario Way',
#   'Port Tinabury',
#   'Saskatchewan',
#   'Djibouti',
#   '779.904.4163',
#   'integrate holistic schemas',
#   '1984-02-11',
#   1193,
#   '2021-02-16 23:04:49.792865',
#   '2021-02-16 23:04:49.792866',
#   '139.0.136.196'),
#  (752,
#   'Natasha Parsons',
#   'denisebrown@davies.com',
#   '84404 Curtis Port',
#   'Edwardsfort',
#   'Northwest Territories',
#   'Cuba',
#   '+1 (783) 415-5266',
#   'scale integrated solutions',
#   '1947-05-21',
#   1505,
#   '2021-02-16 23:04:49.793748',
#   '2021-02-16 23:04:49.793750',
#   '100.39.175.158'),
#  (753,
#   'Kevin George',
#   'malonesherry@white.com',
#   '37950 Shirley Port',
#   'Lake Daniel',
#   'Northwest Territories',
#   'Haiti',
#   '203 515 7902',
#   'benchmark cross-platform web-readiness',
#   '1985-04-25',
#   2028,
#   '2021-02-16 23:04:49.794607',
#   '2021-02-16 23:04:49.794609',
#   '131.243.125.42'),
#  (754,
#   'Paul Wilson',
#   'mgibson@hotmail.com',
#   '90830 Gibbs Cliff',
#   'Barrychester',
#   'Ontario',
#   'Canada',
#   '(127) 032-8105',
#   'deploy impactful communities',
#   '1985-12-31',
#   1689,
#   '2021-02-16 23:04:49.795180',
#   '2021-02-16 23:04:49.795182',
#   '84.228.97.83'),
#  (755,
#   'Brandi Roberson',
#   'kevin83@gamble.com',
#   '9362 Adam Streets Apt. 229',
#   'Trevorville',
#   'New Brunswick',
#   'Iceland',
#   '(599) 806-6861 x050',
#   'leverage B2B info-mediaries',
#   '1972-08-27',
#   2076,
#   '2021-02-16 23:04:49.795900',
#   '2021-02-16 23:04:49.795901',
#   '209.34.236.198'),
#  (756,
#   'Suzanne Moreno',
#   'lauren43@howell.com',
#   '396 Sanders Square Apt. 557',
#   'East Wendy',
#   'British Columbia',
#   'Martinique',
#   '1-849-282-8640',
#   'synthesize impactful mindshare',
#   '1973-02-10',
#   2192,
#   '2021-02-16 23:04:49.796751',
#   '2021-02-16 23:04:49.796752',
#   '168.68.178.146'),
#  (757,
#   'Jeremiah Miller',
#   'jacksongabrielle@hotmail.com',
#   '259 Catherine Park',
#   'Bryanberg',
#   'Newfoundland and Labrador',
#   'Dominica',
#   '1 (137) 423-3044',
#   'repurpose turn-key solutions',
#   '2010-12-12',
#   1129,
#   '2021-02-16 23:04:49.797342',
#   '2021-02-16 23:04:49.797343',
#   '177.59.71.114'),
#  (758,
#   'Colleen Ruiz',
#   'gail23@gmail.com',
#   '3735 Dunn Coves Suite 295',
#   'Rebekahstad',
#   'Saskatchewan',
#   'Togo',
#   '1-570-713-4975',
#   'visualize rich models',
#   '1911-08-14',
#   1364,
#   '2021-02-16 23:04:49.797880',
#   '2021-02-16 23:04:49.797881',
#   '159.65.207.202'),
#  (759,
#   'Christopher Williams',
#   'teresa40@gmail.com',
#   '30944 Phyllis Spur',
#   'New Amy',
#   'New Brunswick',
#   'Taiwan',
#   '1 (897) 634-2752',
#   'synthesize holistic metrics',
#   '1952-11-23',
#   1440,
#   '2021-02-16 23:04:49.798381',
#   '2021-02-16 23:04:49.798382',
#   '188.115.217.80'),
#  (760,
#   'Shelby Snyder',
#   'alexanderjohnson@fisher.com',
#   '5781 Suarez Course Apt. 284',
#   'Meagantown',
#   'Ontario',
#   'Antigua and Barbuda',
#   '(377) 694-8242 x543',
#   'architect scalable eyeballs',
#   '1972-03-01',
#   2457,
#   '2021-02-16 23:04:49.799095',
#   '2021-02-16 23:04:49.799096',
#   '213.35.152.15'),
#  (761,
#   'Kristine Macias',
#   'albertbarnes@acosta.info',
#   '0064 Patrick Mills Apt. 268',
#   'Briggsfurt',
#   'Saskatchewan',
#   'Sudan',
#   '(643) 429-8765 x018',
#   're-contextualize out-of-the-box convergence',
#   '1919-07-01',
#   1840,
#   '2021-02-16 23:04:49.799953',
#   '2021-02-16 23:04:49.799954',
#   '164.103.196.40'),
#  (762,
#   'Kelly Adams',
#   'jeffersonjustin@morgan.org',
#   '99923 Spears Shoal',
#   'Welchtown',
#   'British Columbia',
#   'Azerbaijan',
#   '235-295-2063',
#   'envisioneer ubiquitous interfaces',
#   '1940-08-24',
#   1593,
#   '2021-02-16 23:04:49.800665',
#   '2021-02-16 23:04:49.800667',
#   '193.75.229.62'),
#  (763,
#   'Brandon Warner',
#   'angela13@stevenson-thomas.com',
#   '6843 Andrea Coves',
#   'South Maria',
#   'Prince Edward Island',
#   'Bosnia and Herzegovina',
#   '948 158 9362',
#   'deliver 24/365 synergies',
#   '1947-08-14',
#   1259,
#   '2021-02-16 23:04:49.801347',
#   '2021-02-16 23:04:49.801348',
#   '189.69.212.71'),
#  (764,
#   'David Allen',
#   'carlossummers@yahoo.com',
#   '2321 Jennifer Mill Suite 460',
#   'Melanieton',
#   'Prince Edward Island',
#   'Oman',
#   '667-713-3663 x952',
#   'implement magnetic infrastructures',
#   '1915-02-13',
#   1609,
#   '2021-02-16 23:04:49.801945',
#   '2021-02-16 23:04:49.801946',
#   '128.19.145.38'),
#  (765,
#   'Jamie Mckee',
#   'allisonmegan@chavez.com',
#   '0371 Daniel Estates Apt. 190',
#   'Welchstad',
#   'Saskatchewan',
#   'Egypt',
#   '+1 (510) 571-1784',
#   'brand virtual ROI',
#   '1996-05-26',
#   1514,
#   '2021-02-16 23:04:49.802650',
#   '2021-02-16 23:04:49.802651',
#   '193.5.162.182'),
#  (766,
#   'Mary Castillo',
#   'tamaracarter@gmail.com',
#   '25050 Robert Ranch',
#   'Thompsonchester',
#   'Nunavut',
#   'Pakistan',
#   '397.244.0336',
#   'optimize distributed solutions',
#   '1956-04-17',
#   1325,
#   '2021-02-16 23:04:49.803264',
#   '2021-02-16 23:04:49.803265',
#   '139.255.107.157'),
#  (767,
#   'Yvonne Patel',
#   'icruz@yahoo.com',
#   '0878 Stone Ports',
#   'Tylermouth',
#   'New Brunswick',
#   'Montserrat',
#   '+1 (663) 097-7281',
#   'innovate viral paradigms',
#   '1975-01-28',
#   2260,
#   '2021-02-16 23:04:49.803820',
#   '2021-02-16 23:04:49.803821',
#   '76.194.12.154'),
#  (768,
#   'Joseph Fritz DDS',
#   'iwood@hotmail.com',
#   '50273 Christopher Green',
#   'Mcbrideburgh',
#   'Manitoba',
#   'Kiribati',
#   '248.903.8320',
#   'enable impactful synergies',
#   '2006-11-16',
#   2050,
#   '2021-02-16 23:04:49.804388',
#   '2021-02-16 23:04:49.804389',
#   '154.17.214.255'),
#  (769,
#   'Jessica Alvarado',
#   'bstephenson@yahoo.com',
#   '5544 Kimberly Drive',
#   'Guerrerotown',
#   'Nunavut',
#   'Korea',
#   '+1 (194) 042-6402',
#   'embrace intuitive vortals',
#   '1929-03-11',
#   1455,
#   '2021-02-16 23:04:49.804930',
#   '2021-02-16 23:04:49.804931',
#   '64.201.228.63'),
#  (770,
#   'Jaime Shaffer',
#   'bryantchristopher@williams.com',
#   '88715 Brian Square Apt. 665',
#   'Mannchester',
#   'British Columbia',
#   'Armenia',
#   '355 882 0978',
#   'brand plug-and-play markets',
#   '1982-09-22',
#   1749,
#   '2021-02-16 23:04:49.805783',
#   '2021-02-16 23:04:49.805784',
#   '178.127.24.185'),
#  (771,
#   'Sharon Thomas',
#   'burtondiane@gmail.com',
#   '05351 White Heights',
#   'Port Hannahmouth',
#   'Saskatchewan',
#   'Montenegro',
#   '+1 (587) 034-7279',
#   'maximize bleeding-edge users',
#   '1955-09-28',
#   2094,
#   '2021-02-16 23:04:49.806388',
#   '2021-02-16 23:04:49.806389',
#   '210.190.172.150'),
#  (772,
#   'Justin Black',
#   'jamesfoster@ramirez.com',
#   '02568 Miller Turnpike Apt. 089',
#   'Andersonton',
#   'Newfoundland and Labrador',
#   'Eritrea',
#   '(718) 934-5228 x565',
#   'reinvent out-of-the-box content',
#   '1951-07-19',
#   1091,
#   '2021-02-16 23:04:49.807592',
#   '2021-02-16 23:04:49.807593',
#   '159.31.175.198'),
#  (773,
#   'Kimberly Branch',
#   'sweeneyrachael@barnes.com',
#   '7619 Johnson Passage Suite 458',
#   'Suarezhaven',
#   'New Brunswick',
#   'Mozambique',
#   '1-591-618-6942',
#   'maximize customized synergies',
#   '1920-11-12',
#   1564,
#   '2021-02-16 23:04:49.808607',
#   '2021-02-16 23:04:49.808609',
#   '86.239.142.111'),
#  (774,
#   'Matthew Rosario',
#   'david57@gmail.com',
#   '7178 Cody Unions',
#   'West Taylor',
#   'Nova Scotia',
#   'United States Virgin Islands',
#   '+1 (726) 339-6899',
#   'enhance compelling vortals',
#   '1915-07-07',
#   1471,
#   '2021-02-16 23:04:49.809153',
#   '2021-02-16 23:04:49.809154',
#   '18.7.238.166'),
#  (775,
#   'Anthony Hansen',
#   'ufleming@yahoo.com',
#   '7817 Courtney Plaza',
#   'Samuelport',
#   'Prince Edward Island',
#   'Sao Tome and Principe',
#   '243 923 2199',
#   'drive integrated paradigms',
#   '1991-06-16',
#   1807,
#   '2021-02-16 23:04:49.809714',
#   '2021-02-16 23:04:49.809715',
#   '21.38.194.90'),
#  (776,
#   'Rachel Newton',
#   'gabriel22@castillo.biz',
#   '589 Clark Forge',
#   'Lake Debrashire',
#   'Ontario',
#   'Gambia',
#   '306 163 0028',
#   'evolve scalable systems',
#   '1953-06-24',
#   2244,
#   '2021-02-16 23:04:49.810558',
#   '2021-02-16 23:04:49.810560',
#   '4.93.22.53'),
#  (777,
#   'Cameron Williamson',
#   'richard99@houston.biz',
#   '433 Wilson Lake Apt. 447',
#   'South Robin',
#   'Alberta',
#   'Saint Lucia',
#   '274-511-8943',
#   'streamline 24/365 e-commerce',
#   '1987-12-15',
#   1462,
#   '2021-02-16 23:04:49.811354',
#   '2021-02-16 23:04:49.811356',
#   '204.76.74.133'),
#  (778,
#   'Dana Carlson PhD',
#   'lmccullough@yahoo.com',
#   '975 Edward Plains',
#   'Smithville',
#   'Prince Edward Island',
#   'Angola',
#   '600-787-3186 x236',
#   'enable interactive applications',
#   '2010-07-20',
#   2364,
#   '2021-02-16 23:04:49.811936',
#   '2021-02-16 23:04:49.811937',
#   '170.240.250.50'),
#  (779,
#   'David Evans',
#   'wrodriguez@wallace.biz',
#   '774 Smith Stream Apt. 420',
#   'Angelaborough',
#   'Northwest Territories',
#   'Georgia',
#   '1-412-515-7515',
#   'leverage world-class synergies',
#   '1963-04-15',
#   2000,
#   '2021-02-16 23:04:49.812607',
#   '2021-02-16 23:04:49.812608',
#   '168.175.61.195'),
#  (780,
#   'Derek Johnston',
#   'kaylacole@miller.com',
#   '8850 Robbins Plain Suite 663',
#   'North Johnmouth',
#   'Alberta',
#   'Oman',
#   '800-037-2999',
#   'morph B2C e-tailers',
#   '1925-06-27',
#   1806,
#   '2021-02-16 23:04:49.813346',
#   '2021-02-16 23:04:49.813348',
#   '183.77.25.27'),
#  (781,
#   'Daniel Williamson',
#   'harrismartha@gmail.com',
#   '886 Vargas Grove',
#   'Joshuaport',
#   'Yukon Territory',
#   'Honduras',
#   '+1 (296) 553-0142',
#   'deliver magnetic e-tailers',
#   '1969-09-05',
#   1362,
#   '2021-02-16 23:04:49.813983',
#   '2021-02-16 23:04:49.813984',
#   '140.19.249.146'),
#  (782,
#   'Melissa Lewis',
#   'wilsonangel@hotmail.com',
#   '342 Kenneth Isle',
#   'Rebeccaville',
#   'Manitoba',
#   'Belarus',
#   '170 451 4093',
#   'optimize e-business applications',
#   '1951-07-27',
#   1237,
#   '2021-02-16 23:04:49.814578',
#   '2021-02-16 23:04:49.814580',
#   '122.147.211.121'),
#  (783,
#   'Evan Lee',
#   'lisalittle@yahoo.com',
#   '523 Katherine Fields Apt. 199',
#   'Jamesside',
#   'Northwest Territories',
#   'Mauritania',
#   '580-772-9823',
#   'implement 24/7 interfaces',
#   '1935-07-16',
#   1852,
#   '2021-02-16 23:04:49.815211',
#   '2021-02-16 23:04:49.815213',
#   '123.90.183.181'),
#  (784,
#   'Jordan Parrish',
#   'aramirez@hotmail.com',
#   '155 Schmidt Roads',
#   'Brendaborough',
#   'Manitoba',
#   'Slovakia (Slovak Republic)',
#   '(514) 447-5376 x235',
#   'generate ubiquitous interfaces',
#   '1971-07-11',
#   2417,
#   '2021-02-16 23:04:49.815769',
#   '2021-02-16 23:04:49.815770',
#   '134.212.48.227'),
#  (785,
#   'Zachary Delgado',
#   'amanda72@yahoo.com',
#   '52311 Richards Crescent Suite 471',
#   'East Tammybury',
#   'Newfoundland and Labrador',
#   'Micronesia',
#   '449-922-6046',
#   'transition out-of-the-box channels',
#   '1971-07-29',
#   2198,
#   '2021-02-16 23:04:49.816315',
#   '2021-02-16 23:04:49.816316',
#   '32.62.137.103'),
#  (786,
#   'Jonathan Kelley',
#   'ronald17@yahoo.com',
#   '2496 Scott Square',
#   'Henryville',
#   'Prince Edward Island',
#   'Israel',
#   '759-826-7457',
#   'enable viral e-markets',
#   '1919-03-18',
#   1740,
#   '2021-02-16 23:04:49.816845',
#   '2021-02-16 23:04:49.816846',
#   '44.198.36.99'),
#  (787,
#   'Adam Church',
#   'rcook@yahoo.com',
#   '8914 Todd Radial',
#   'Randyhaven',
#   'Newfoundland and Labrador',
#   'Rwanda',
#   '392-437-4352 x255',
#   'synergize killer users',
#   '1970-04-12',
#   2411,
#   '2021-02-16 23:04:49.817393',
#   '2021-02-16 23:04:49.817394',
#   '192.61.79.148'),
#  (788,
#   'David King',
#   'daniel71@gmail.com',
#   '5237 Daniel Circles',
#   'Johnsonton',
#   'Quebec',
#   'Kuwait',
#   '+1 (231) 369-6128',
#   'implement revolutionary networks',
#   '1950-01-25',
#   2497,
#   '2021-02-16 23:04:49.817939',
#   '2021-02-16 23:04:49.817940',
#   '83.245.135.191'),
#  (789,
#   'Nathan Bright',
#   'fcook@black.net',
#   '8810 Devon Canyon',
#   'South Kyle',
#   'Prince Edward Island',
#   'Burkina Faso',
#   '717-645-4961 x591',
#   'iterate global info-mediaries',
#   '1986-11-18',
#   1590,
#   '2021-02-16 23:04:49.818730',
#   '2021-02-16 23:04:49.818731',
#   '178.225.88.133'),
#  (790,
#   'Marcia Russell',
#   'amandasmith@rodriguez.com',
#   '7322 Laura Ports',
#   'Lake Rebeccaview',
#   'Newfoundland and Labrador',
#   'Netherlands Antilles',
#   '1-604-302-8613',
#   'transform real-time metrics',
#   '1935-10-19',
#   1202,
#   '2021-02-16 23:04:49.819591',
#   '2021-02-16 23:04:49.819592',
#   '22.104.33.98'),
#  (791,
#   'Martin Torres',
#   'timothywells@reyes-hill.com',
#   '063 Perry Ports Suite 481',
#   'Campbellstad',
#   'Prince Edward Island',
#   'Ecuador',
#   '(612) 786-9362 x260',
#   'orchestrate global mindshare',
#   '1913-04-05',
#   1923,
#   '2021-02-16 23:04:49.820415',
#   '2021-02-16 23:04:49.820416',
#   '52.39.206.133'),
#  (792,
#   'Grace Douglas',
#   'timothycross@choi.net',
#   '8505 Jose Corners Apt. 152',
#   'East Deanmouth',
#   'Nunavut',
#   'Greece',
#   '(905) 097-0248 x811',
#   'expedite dot-com paradigms',
#   '2000-01-26',
#   2147,
#   '2021-02-16 23:04:49.821289',
#   '2021-02-16 23:04:49.821292',
#   '11.147.229.129'),
#  (793,
#   'Brittany Hamilton',
#   'jwagner@price.com',
#   '42350 Jones Mission',
#   'Nicoleland',
#   'Saskatchewan',
#   'Italy',
#   '855-184-1371',
#   'architect viral relationships',
#   '1982-04-14',
#   1019,
#   '2021-02-16 23:04:49.822774',
#   '2021-02-16 23:04:49.822776',
#   '161.117.29.106'),
#  (794,
#   'Sheryl Walters',
#   'barbarafoster@fuller.com',
#   '2730 Thomas Radial Suite 660',
#   'Port Jacobbury',
#   'Nova Scotia',
#   'Jamaica',
#   '(893) 581-4420 x662',
#   'utilize intuitive supply-chains',
#   '1936-06-06',
#   2083,
#   '2021-02-16 23:04:49.824096',
#   '2021-02-16 23:04:49.824098',
#   '205.159.36.32'),
#  (795,
#   'Sharon Smith',
#   'riveraarthur@gmail.com',
#   '09402 Davis Squares',
#   'North Lisa',
#   'Saskatchewan',
#   'Niue',
#   '(397) 776-5136 x398',
#   'syndicate cutting-edge eyeballs',
#   '2020-01-24',
#   2403,
#   '2021-02-16 23:04:49.825242',
#   '2021-02-16 23:04:49.825244',
#   '205.242.27.140'),
#  (796,
#   'John Garcia',
#   'huertabrandi@gmail.com',
#   '03353 Mark Camp Apt. 691',
#   'East Rickfort',
#   'Northwest Territories',
#   'Macao',
#   '(909) 667-1672 x444',
#   'enable frictionless portals',
#   '1980-02-10',
#   1623,
#   '2021-02-16 23:04:49.826323',
#   '2021-02-16 23:04:49.826325',
#   '55.58.98.184'),
#  (797,
#   'Shaun Watson',
#   'harrisshelly@gmail.com',
#   '305 James Terrace Suite 228',
#   'South Virginia',
#   'British Columbia',
#   'Namibia',
#   '1 (661) 573-8399',
#   'brand best-of-breed content',
#   '1931-03-21',
#   1306,
#   '2021-02-16 23:04:49.827366',
#   '2021-02-16 23:04:49.827367',
#   '199.228.87.231'),
#  (798,
#   'Amber Jones',
#   'cgonzales@anderson.net',
#   '2260 Alvarez Mountains Suite 526',
#   'Levybury',
#   'British Columbia',
#   'Wallis and Futuna',
#   '741 373 4343',
#   'exploit enterprise interfaces',
#   '2008-06-23',
#   1542,
#   '2021-02-16 23:04:49.828884',
#   '2021-02-16 23:04:49.828886',
#   '184.181.89.2'),
#  (799,
#   'Pamela Parker',
#   'xwinters@warren.biz',
#   '38191 Ann Junctions',
#   'Pattersonside',
#   'Northwest Territories',
#   'Kuwait',
#   '219-622-2002 x230',
#   'grow plug-and-play vortals',
#   '1949-06-20',
#   1569,
#   '2021-02-16 23:04:49.830332',
#   '2021-02-16 23:04:49.830334',
#   '142.176.41.74'),
#  (800,
#   'Brian Wagner',
#   'aboyer@yahoo.com',
#   '3245 Jennifer Falls',
#   'West Kristenchester',
#   'British Columbia',
#   'Japan',
#   '1-753-146-8137',
#   'harness dynamic technologies',
#   '1974-05-19',
#   1544,
#   '2021-02-16 23:04:49.831330',
#   '2021-02-16 23:04:49.831332',
#   '160.7.192.90'),
#  (801,
#   'Amber Clarke',
#   'eric71@butler.com',
#   '0518 Mcintyre Cape Apt. 483',
#   'Hallfort',
#   'Saskatchewan',
#   'South Africa',
#   '1-645-434-3557',
#   'evolve wireless e-tailers',
#   '1990-10-30',
#   1775,
#   '2021-02-16 23:04:49.832888',
#   '2021-02-16 23:04:49.832889',
#   '30.76.142.164'),
#  (802,
#   'Nicholas Smith',
#   'sbrown@ayala.com',
#   '0393 Gonzalez Corners Apt. 047',
#   'Churchville',
#   'Saskatchewan',
#   'Australia',
#   '205-816-4039',
#   'implement front-end architectures',
#   '1925-04-08',
#   1363,
#   '2021-02-16 23:04:49.834113',
#   '2021-02-16 23:04:49.834115',
#   '102.222.236.174'),
#  (803,
#   'Brandon Watson MD',
#   'eddieford@johnson.info',
# ...
#   '5389 Wilson Coves',
#   'Lake Jackburgh',
#   'Prince Edward Island',
#   'Papua New Guinea',
#   '(412) 058-1971 x500',
#   'enhance bricks-and-clicks channels',
#   '1972-02-06',
#   2159,
#   '2021-02-16 23:04:49.931135',
#   '2021-02-16 23:04:49.931136',
#   '82.37.6.16'),
#  (949,
#   'Ryan Brooks',
#   'ngreen@gmail.com',
#   '517 Brent Crest',
#   'Riveraburgh',
#   'British Columbia',
#   'Bahamas',
#   '1 (439) 440-6716',
#   'maximize killer ROI',
#   '1961-10-26',
#   2095,
#   '2021-02-16 23:04:49.931694',
#   '2021-02-16 23:04:49.931695',
#   '223.229.176.139'),
#  (950,
#   'Kenneth Henderson',
#   'david09@gmail.com',
#   '48988 Mooney Oval Suite 575',
#   'Alanmouth',
#   'Nunavut',
#   'Honduras',
#   '+1 (209) 119-9519',
#   'cultivate global metrics',
#   '1997-06-03',
#   1388,
#   '2021-02-16 23:04:49.932261',
#   '2021-02-16 23:04:49.932262',
#   '167.55.171.20'),
#  (951,
#   'Douglas Murphy',
#   'anavarro@cannon.com',
#   '06170 Carpenter Ports',
#   'Cruzfort',
#   'Northwest Territories',
#   'Congo',
#   '826-044-9858',
#   'e-enable magnetic systems',
#   '1907-03-26',
#   2392,
#   '2021-02-16 23:04:49.933048',
#   '2021-02-16 23:04:49.933049',
#   '115.217.7.213'),
#  (952,
#   'Kathleen Miller',
#   'emartinez@yahoo.com',
#   '9872 Johnson Parkways',
#   'North Carlostown',
#   'Northwest Territories',
#   'Western Sahara',
#   '+1 (416) 062-3626',
#   'enable compelling networks',
#   '1976-02-18',
#   2318,
#   '2021-02-16 23:04:49.933624',
#   '2021-02-16 23:04:49.933625',
#   '212.159.226.145'),
#  (953,
#   'Jody Mitchell',
#   'lhebert@hotmail.com',
#   '3330 Robinson Passage Suite 077',
#   'Ryanshire',
#   'Nunavut',
#   'Bahamas',
#   '569-060-2523',
#   'synergize compelling bandwidth',
#   '1918-05-17',
#   1537,
#   '2021-02-16 23:04:49.934202',
#   '2021-02-16 23:04:49.934203',
#   '131.183.226.149'),
#  (954,
#   'Thomas Cabrera',
#   'jthomas@hotmail.com',
#   '942 Jennifer Village',
#   'Tinamouth',
#   'New Brunswick',
#   'Maldives',
#   '(439) 112-4463 x117',
#   'reinvent revolutionary e-services',
#   '1916-05-16',
#   1835,
#   '2021-02-16 23:04:49.934718',
#   '2021-02-16 23:04:49.934719',
#   '150.108.147.100'),
#  (955,
#   'Clarence Crawford',
#   'crawfordgeorge@bradley-reynolds.com',
#   '63321 Ellis Cove Suite 381',
#   'New Kayla',
#   'Newfoundland and Labrador',
#   'Sierra Leone',
#   '589-192-4146',
#   'repurpose dynamic e-markets',
#   '1968-01-19',
#   2429,
#   '2021-02-16 23:04:49.935493',
#   '2021-02-16 23:04:49.935494',
#   '139.56.135.101'),
#  (956,
#   'Amy Contreras',
#   'stacey16@nelson.info',
#   '426 Erin River',
#   'East Michaelport',
#   'New Brunswick',
#   'Palestinian Territory',
#   '+1 (271) 701-8317',
#   'generate efficient ROI',
#   '1927-12-29',
#   1017,
#   '2021-02-16 23:04:49.936235',
#   '2021-02-16 23:04:49.936236',
#   '213.59.17.30'),
#  (957,
#   'Joseph Warren',
#   'davidjones@hotmail.com',
#   '3758 Hardy Extension',
#   'Harriston',
#   'Manitoba',
#   'Iraq',
#   '1 (186) 844-1322',
#   'integrate collaborative ROI',
#   '1911-08-02',
#   2379,
#   '2021-02-16 23:04:49.936847',
#   '2021-02-16 23:04:49.936848',
#   '116.165.136.9'),
#  (958,
#   'Jessica Baker',
#   'fallison@neal-mcdonald.com',
#   '82387 Paul Mountains Apt. 081',
#   'Port Jamesfort',
#   'Manitoba',
#   'Ecuador',
#   '(688) 876-2162 x386',
#   'orchestrate one-to-one users',
#   '1930-10-13',
#   1550,
#   '2021-02-16 23:04:49.937564',
#   '2021-02-16 23:04:49.937565',
#   '202.41.239.158'),
#  (959,
#   'John Martin',
#   'cwalls@miller.com',
#   '670 Bradley Views Suite 522',
#   'Phammouth',
#   'Yukon Territory',
#   'Nauru',
#   '(540) 876-2957',
#   'target 24/7 portals',
#   '1931-10-23',
#   1352,
#   '2021-02-16 23:04:49.938391',
#   '2021-02-16 23:04:49.938392',
#   '161.25.97.38'),
#  (960,
#   'Mark Moody',
#   'mendozarobert@hotmail.com',
#   '742 John Mills Apt. 260',
#   'East Tamarastad',
#   'Newfoundland and Labrador',
#   'Micronesia',
#   '1 (537) 724-3778',
#   'utilize cutting-edge supply-chains',
#   '1999-07-09',
#   2473,
#   '2021-02-16 23:04:49.939503',
#   '2021-02-16 23:04:49.939505',
#   '199.161.71.183'),
#  (961,
#   'Andrea Reyes',
#   'melissawest@rodriguez-navarro.com',
#   '5999 Danielle Centers Apt. 330',
#   'Dawsonside',
#   'New Brunswick',
#   'Botswana',
#   '(929) 513-1514 x416',
#   'integrate killer e-markets',
#   '1978-08-04',
#   1776,
#   '2021-02-16 23:04:49.940551',
#   '2021-02-16 23:04:49.940553',
#   '120.166.179.83'),
#  (962,
#   'Rachael Robinson',
#   'kbryant@howell.net',
#   '43291 Corey Spurs',
#   'North Richardport',
#   'Yukon Territory',
#   'Mauritania',
#   '(607) 067-3738 x954',
#   'redefine integrated web services',
#   '1926-10-19',
#   2215,
#   '2021-02-16 23:04:49.941363',
#   '2021-02-16 23:04:49.941364',
#   '169.102.80.182'),
#  (963,
#   'Dorothy Harrington',
#   'pamelajames@gmail.com',
#   '11188 Morris Manor Apt. 474',
#   'Hicksmouth',
#   'Newfoundland and Labrador',
#   'Jersey',
#   '(224) 335-0656',
#   'maximize front-end markets',
#   '1993-06-22',
#   1566,
#   '2021-02-16 23:04:49.942014',
#   '2021-02-16 23:04:49.942015',
#   '95.77.124.25'),
#  (964,
#   'Jeffrey Nelson',
#   'danielrandolph@perez-tyler.com',
#   '33295 Chapman Spurs',
#   'Petersonborough',
#   'Ontario',
#   'Saint Helena',
#   '657-919-8085 x354',
#   'exploit cutting-edge markets',
#   '2011-03-04',
#   1775,
#   '2021-02-16 23:04:49.942824',
#   '2021-02-16 23:04:49.942825',
#   '50.181.1.229'),
#  (965,
#   'Gary Mccoy',
#   'jchandler@hotmail.com',
#   '1480 Cervantes Skyway Apt. 676',
#   'Butlerburgh',
#   'Ontario',
#   'Malta',
#   '1 (298) 401-1905',
#   'innovate global partnerships',
#   '1913-04-24',
#   1888,
#   '2021-02-16 23:04:49.943412',
#   '2021-02-16 23:04:49.943413',
#   '168.153.54.140'),
#  (966,
#   'James Short',
#   'sandra60@jennings.info',
#   '05503 Mckenzie Trail',
#   'Amyside',
#   'Northwest Territories',
#   'Ghana',
#   '1 (874) 163-7702',
#   'target intuitive web services',
#   '1924-07-01',
#   1850,
#   '2021-02-16 23:04:49.944081',
#   '2021-02-16 23:04:49.944082',
#   '153.60.141.117'),
#  (967,
#   'Michael Li',
#   'zhogan@baker-johnson.net',
#   '94871 Hunter Course',
#   'Lozanoberg',
#   'Prince Edward Island',
#   'Samoa',
#   '(151) 246-4176 x389',
#   'evolve mission-critical vortals',
#   '1977-06-02',
#   1930,
#   '2021-02-16 23:04:49.944842',
#   '2021-02-16 23:04:49.944843',
#   '32.234.114.245'),
#  (968,
#   'Robert Hanson',
#   'zgiles@smith-barber.biz',
#   '8267 Wagner Courts Suite 337',
#   'Bakermouth',
#   'Newfoundland and Labrador',
#   'Montserrat',
#   '609 695 8468',
#   'leverage end-to-end infrastructures',
#   '1973-07-30',
#   2025,
#   '2021-02-16 23:04:49.945601',
#   '2021-02-16 23:04:49.945602',
#   '89.133.17.37'),
#  (969,
#   'Mike Trujillo',
#   'millershelley@gibson.biz',
#   '834 Matthew Mountains Suite 600',
#   'Michaelchester',
#   'Nunavut',
#   'Belgium',
#   '803.388.4331',
#   'streamline best-of-breed metrics',
#   '1991-05-12',
#   2150,
#   '2021-02-16 23:04:49.946289',
#   '2021-02-16 23:04:49.946290',
#   '208.31.210.209'),
#  (970,
#   'Julie Carrillo',
#   'melissachapman@hotmail.com',
#   '5384 Steven Loop Apt. 724',
#   'East Cliffordside',
#   'Saskatchewan',
#   'Mayotte',
#   '1-927-268-0688',
#   'empower real-time e-commerce',
#   '1988-03-21',
#   2295,
#   '2021-02-16 23:04:49.946912',
#   '2021-02-16 23:04:49.946914',
#   '180.156.255.13'),
#  (971,
#   'Tiffany Grimes',
#   'diazcatherine@yahoo.com',
#   '78645 Robert Garden',
#   'North Richard',
#   'Nova Scotia',
#   'El Salvador',
#   '231.748.2822',
#   'morph back-end e-services',
#   '1964-01-23',
#   1174,
#   '2021-02-16 23:04:49.947493',
#   '2021-02-16 23:04:49.947494',
#   '88.231.163.205'),
#  (972,
#   'Matthew Spencer',
#   'josemccarthy@levine.biz',
#   '7713 Timothy Meadow Suite 415',
#   'West Lindsey',
#   'Newfoundland and Labrador',
#   'Montserrat',
#   '1 (337) 614-6561',
#   'revolutionize proactive experiences',
#   '2001-03-29',
#   2432,
#   '2021-02-16 23:04:49.948188',
#   '2021-02-16 23:04:49.948190',
#   '77.53.243.88'),
#  (973,
#   'Karen Williams',
#   'shannon54@kent-hicks.biz',
#   '77165 Tonya Light',
#   'West April',
#   'Northwest Territories',
#   'Panama',
#   '(590) 918-5740 x961',
#   'enhance frictionless partnerships',
#   '1935-05-24',
#   2438,
#   '2021-02-16 23:04:49.948892',
#   '2021-02-16 23:04:49.948893',
#   '191.127.216.27'),
#  (974,
#   'Michael Dixon',
#   'rachel27@johnson.com',
#   '038 Jason Plains Apt. 403',
#   'East Michael',
#   'Yukon Territory',
#   'Lesotho',
#   '588 008 6908',
#   're-intermediate seamless channels',
#   '2018-01-21',
#   1486,
#   '2021-02-16 23:04:49.949517',
#   '2021-02-16 23:04:49.949518',
#   '113.219.161.18'),
#  (975,
#   'Anthony Estes',
#   'nicholasrasmussen@gmail.com',
#   '14368 Gary Trafficway',
#   'Port Danielle',
#   'Yukon Territory',
#   'Lebanon',
#   '1 (649) 604-2274',
#   'deploy best-of-breed schemas',
#   '2009-10-21',
#   1291,
#   '2021-02-16 23:04:49.950096',
#   '2021-02-16 23:04:49.950097',
#   '207.139.85.239'),
#  (976,
#   'Monique Wilson',
#   'christopher35@yahoo.com',
#   '12167 Christina Station',
#   'Garrettburgh',
#   'Nova Scotia',
#   'Latvia',
#   '1 (457) 938-8239',
#   'drive 24/7 portals',
#   '1954-06-20',
#   1951,
#   '2021-02-16 23:04:49.950785',
#   '2021-02-16 23:04:49.950786',
#   '151.95.5.16'),
#  (977,
#   'Kristin Morales',
#   'andrewmiller@robinson-morrison.com',
#   '44367 Graves Extensions Apt. 314',
#   'Autumnview',
#   'British Columbia',
#   'Niue',
#   '(347) 142-8855 x146',
#   'brand front-end e-business',
#   '1984-11-10',
#   1351,
#   '2021-02-16 23:04:49.951606',
#   '2021-02-16 23:04:49.951607',
#   '149.235.111.106'),
#  (978,
#   'Amber Brown',
#   'jennifergreen@yahoo.com',
#   '5540 Joseph Ramp Apt. 584',
#   'East Crystal',
#   'Newfoundland and Labrador',
#   'South Africa',
#   '+1 (513) 443-8597',
#   'expedite back-end initiatives',
#   '1939-12-01',
#   1209,
#   '2021-02-16 23:04:49.952202',
#   '2021-02-16 23:04:49.952203',
#   '28.89.236.89'),
#  (979,
#   'Linda Simpson',
#   'nriley@hotmail.com',
#   '84719 James Trafficway Suite 363',
#   'Justinchester',
#   'Nova Scotia',
#   'Sierra Leone',
#   '(452) 825-0505 x433',
#   'unleash collaborative metrics',
#   '1929-07-19',
#   1295,
#   '2021-02-16 23:04:49.952749',
#   '2021-02-16 23:04:49.952751',
#   '168.147.202.53'),
#  (980,
#   'Tanya Hawkins',
#   'xnorris@hotmail.com',
#   '4925 Rachel Meadow',
#   'New Williamfurt',
#   'Ontario',
#   'Liberia',
#   '1-256-148-6318',
#   'aggregate magnetic action-items',
#   '2004-11-14',
#   1987,
#   '2021-02-16 23:04:49.953284',
#   '2021-02-16 23:04:49.953285',
#   '171.109.175.196'),
#  (981,
#   'Derrick Dunlap',
#   'jgreen@buck.com',
#   '70850 William Drive',
#   'Tiffanyview',
#   'British Columbia',
#   'Tanzania',
#   '(548) 634-9369',
#   'maximize cross-platform systems',
#   '1973-09-02',
#   2047,
#   '2021-02-16 23:04:49.954051',
#   '2021-02-16 23:04:49.954053',
#   '223.205.125.207'),
#  (982,
#   'Gwendolyn Douglas',
#   'sheltonmatthew@yahoo.com',
#   '9894 Jennifer Spring',
#   'Lovefort',
#   'Nunavut',
#   'New Caledonia',
#   '(626) 875-1670 x197',
#   'disintermediate innovative solutions',
#   '1987-09-04',
#   1583,
#   '2021-02-16 23:04:49.954685',
#   '2021-02-16 23:04:49.954687',
#   '166.183.222.33'),
#  (983,
#   'Edward Morgan',
#   'patricia79@carter-sparks.biz',
#   '003 Elizabeth Fork',
#   'New Dustin',
#   'Newfoundland and Labrador',
#   'Thailand',
#   '(381) 116-9418',
#   'e-enable next-generation e-business',
#   '1921-10-23',
#   1333,
#   '2021-02-16 23:04:49.955366',
#   '2021-02-16 23:04:49.955367',
#   '190.117.184.0'),
#  (984,
#   'Angela Gray',
#   'urobertson@hotmail.com',
#   '5043 Craig Garden',
#   'Lake Johnfort',
#   'Saskatchewan',
#   'Ethiopia',
#   '112.354.8912',
#   'benchmark efficient ROI',
#   '1981-12-08',
#   1700,
#   '2021-02-16 23:04:49.955897',
#   '2021-02-16 23:04:49.955898',
#   '46.247.86.102'),
#  (985,
#   'Larry Mcpherson PhD',
#   'pochoa@moore.org',
#   '930 Kristin Burgs Suite 972',
#   'Bensonborough',
#   'Quebec',
#   'Pitcairn Islands',
#   '1 (697) 606-4133',
#   'matrix world-class portals',
#   '1996-07-08',
#   2163,
#   '2021-02-16 23:04:49.956703',
#   '2021-02-16 23:04:49.956704',
#   '208.57.94.178'),
#  (986,
#   'Chad Carter Jr.',
#   'hbryant@chen.com',
#   '21632 Gonzalez Greens',
#   'North Rogerville',
#   'Manitoba',
#   'Jamaica',
#   '+1 (983) 688-0358',
#   'engage distributed schemas',
#   '2017-12-01',
#   2343,
#   '2021-02-16 23:04:49.957373',
#   '2021-02-16 23:04:49.957374',
#   '12.248.113.39'),
#  (987,
#   'Debra Jones',
#   'hoovertammy@yahoo.com',
#   '71869 Brittany Lock Suite 070',
#   'Orrhaven',
#   'Northwest Territories',
#   'Sri Lanka',
#   '(484) 998-1784 x140',
#   'seize enterprise channels',
#   '1909-01-26',
#   2422,
#   '2021-02-16 23:04:49.958016',
#   '2021-02-16 23:04:49.958018',
#   '192.175.53.91'),
#  (988,
#   'Ryan Parsons',
#   'vwoodard@sellers.com',
#   '812 Derrick Plains Apt. 355',
#   'Salazarbury',
#   'Nova Scotia',
#   'Serbia',
#   '+1 (565) 779-5968',
#   'iterate real-time e-services',
#   '1910-09-30',
#   2026,
#   '2021-02-16 23:04:49.958864',
#   '2021-02-16 23:04:49.958865',
#   '165.28.144.78'),
#  (989,
#   'Brett Clark',
#   'hernandezmarcus@gray.com',
#   '8513 Collins Trail Suite 226',
#   'Lake Marioborough',
#   'New Brunswick',
#   'Tonga',
#   '+1 (529) 459-9714',
#   'revolutionize viral metrics',
#   '1982-11-13',
#   1828,
#   '2021-02-16 23:04:49.959589',
#   '2021-02-16 23:04:49.959590',
#   '181.72.209.242'),
#  (990,
#   'Jill Smith',
#   'robertsleah@gmail.com',
#   '506 Ann Via Suite 698',
#   'New Roger',
#   'Quebec',
#   'British Indian Ocean Territory (Chagos Archipelago)',
#   '965-016-5649 x739',
#   'matrix holistic initiatives',
#   '2011-01-15',
#   1315,
#   '2021-02-16 23:04:49.960188',
#   '2021-02-16 23:04:49.960189',
#   '70.123.11.45'),
#  (991,
#   'Cheryl Burton',
#   'sawyermegan@rivera.biz',
#   '3235 Scott Bypass Apt. 231',
#   'New James',
#   'Ontario',
#   'Cambodia',
#   '1-661-341-0067',
#   'whiteboard out-of-the-box niches',
#   '2003-07-29',
#   1277,
#   '2021-02-16 23:04:49.960879',
#   '2021-02-16 23:04:49.960880',
#   '90.65.28.1'),
#  (992,
#   'Jennifer Miller',
#   'christinerichard@yahoo.com',
#   '7008 Richards Island',
#   'Lake Cory',
#   'Northwest Territories',
#   'Malaysia',
#   '1-611-946-0783',
#   'drive B2C action-items',
#   '2005-11-02',
#   2355,
#   '2021-02-16 23:04:49.961482',
#   '2021-02-16 23:04:49.961483',
#   '223.209.114.83'),
#  (993,
#   'Christopher Winters',
#   'racheldavenport@miller.info',
#   '01304 Sheryl Flats',
#   'West Nicole',
#   'Yukon Territory',
#   'Gibraltar',
#   '687.459.9367',
#   'architect viral e-business',
#   '1906-05-22',
#   1519,
#   '2021-02-16 23:04:49.962308',
#   '2021-02-16 23:04:49.962309',
#   '190.250.155.81'),
#  (994,
#   'John Weaver',
#   'kathydelgado@hotmail.com',
#   '505 Burgess Mill Suite 695',
#   'North Susan',
#   'Manitoba',
#   'Dominican Republic',
#   '(887) 913-1324 x437',
#   'empower visionary deliverables',
#   '1973-02-27',
#   1353,
#   '2021-02-16 23:04:49.962917',
#   '2021-02-16 23:04:49.962918',
#   '164.196.4.237'),
#  (995,
#   'Edwin Edwards',
#   'taylor28@walker.com',
#   '331 Mason Fork',
#   'South Jamesburgh',
#   'Saskatchewan',
#   'Germany',
#   '963.846.2915',
#   'enhance B2C infrastructures',
#   '2014-02-13',
#   1035,
#   '2021-02-16 23:04:49.963702',
#   '2021-02-16 23:04:49.963703',
#   '201.246.178.107'),
#  (996,
#   'Julie Jacobs',
#   'barbaranelson@yahoo.com',
#   '6920 Sharon Meadows',
#   'Port Tarafort',
#   'Ontario',
#   'Finland',
#   '(665) 051-0533',
#   'generate seamless markets',
#   '1931-12-08',
#   2234,
#   '2021-02-16 23:04:49.964297',
#   '2021-02-16 23:04:49.964298',
#   '134.28.138.41'),
#  (997,
#   'Candice Estrada',
#   'watsonamber@gray.net',
#   '03493 Cynthia Inlet Suite 081',
#   'Craneside',
#   'British Columbia',
#   'Syrian Arab Republic',
#   '1-706-535-3274',
#   'redefine bricks-and-clicks communities',
#   '1976-07-28',
#   1840,
#   '2021-02-16 23:04:49.965001',
#   '2021-02-16 23:04:49.965002',
#   '109.121.24.100'),
#  (998,
#   'David Rodriguez',
#   'jane33@cochran-gordon.org',
#   '210 King Crossing',
#   'West Theresa',
#   'Quebec',
#   'Jersey',
#   '(872) 758-4073 x248',
#   're-intermediate vertical web-readiness',
#   '1929-01-26',
#   1018,
#   '2021-02-16 23:04:49.965728',
#   '2021-02-16 23:04:49.965729',
#   '182.76.68.180'),
#  (999,
#   'Kevin Benton',
#   'donnagallagher@gmail.com',
#   '2754 David Crest Suite 483',
#   'Sethfort',
#   'Nunavut',
#   'Marshall Islands',
#   '1 (953) 357-5468',
#   'repurpose leading-edge users',
#   '1941-11-08',
#   1550,
#   '2021-02-16 23:04:49.966316',
#   '2021-02-16 23:04:49.966317',
#   '158.190.78.56'),
#  (1000,
#   'Brett Jackson',
#   'courtneypatterson@hotmail.com',
#   '20068 Jill Lodge Apt. 153',
#   'Port Jennaton',
#   'Ontario',
#   'Cocos (Keeling) Islands',
#   '958.146.5033',
#   're-intermediate magnetic interfaces',
#   '1907-09-15',
#   2254,
#   '2021-02-16 23:04:49.966923',
#   '2021-02-16 23:04:49.966924',
#   '36.166.236.223')]

# %% [markdown]
# Finally, the last step,
# Using the code block below, combined with what you have learned above, and the Lecture notes,
# Craft a SQL Query that will return the `name` of no more than `20` `people` with a `heatmap` greater than `1500`

# %%
import sqlite3
from pprint import pprint
#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

selectStatement = """SELECT name, heatmap FROM people WHERE heatmap >= 1500 LIMIT 20"""

myCursor.execute(selectStatement)

results = myCursor.fetchall()
pprint(results)
# Out:
# [('Kelly Andrews', 2424),
#  ('Aaron Hale', 1998),
#  ('Michael Newton', 1759),
#  ('Olivia Rowe', 2299),
#  ('Tara Combs', 1979),
#  ('William Myers', 1568),
#  ('Wendy Mason', 1801),
#  ('Ashley Bush', 2111),
#  ('Christine Smith', 2487),
#  ('Anthony Anderson', 2049),
#  ('Laura Chapman', 1642),
#  ('Dr. Craig James MD', 1917),
#  ('Elizabeth Mcdonald', 2199),
#  ('Lori Hammond', 1793),
#  ('Jeremy Wilson', 1750),
#  ('Marisa Scott', 1811),
#  ('Alejandro Evans', 2194),
#  ('Michael Russell', 2403),
#  ('Dustin Smith', 1548),
#  ('Kathy Jones', 2437)]

# %% [markdown]
# Your submission will contain, as usual, a link to your completed colab notebook, but in addition to that, you will download a copy of your social_network.db file and upload it to D2L. To download the file, right click it from the Files menu on the left of the Notebook.
